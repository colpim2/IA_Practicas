# %% [markdown]
# ## **Práctica 2: Reglas de asociación**
#
# Nombre:Castillo Montes Pamela
#
# Email:pamela.castillo.montes@gmail.com

# %% [markdown]
# **Objetivo**
#
# Analizar las transacciones y obtener reglas significativas (patrones) de los productos vendidos en un comercio minorista en Francia.
# Los datos son transacciones de un comercio de un periodo de una semana (7 días).
#
# **Características:**
#
# * Ítems (20 productos)
# * 7500 transacciones
#
#
# Fuente de datos: store_data.csv

# %% [markdown]
# #### **1) Importar las bibliotecas necesarias**

# %%
# !pip install apyori # pip es un administrador de paquetes de Python. Se instala el paquete Apyori
# Out:
# Collecting apyori
#   Downloading apyori-1.1.2.tar.gz (8.6 kB)
# Building wheels for collected packages: apyori
#   Building wheel for apyori (setup.py): started
#   Building wheel for apyori (setup.py): finished with status 'done'
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5979 sha256=aab24690f4edb3b041ef3bef12ef1715b32cf57a99c0f4caaf4c6a617eb10688
#   Stored in directory: c:\users\mipc\appdata\local\pip\cache\wheels\1b\02\6c\a45230be8603bd95c0a51cd2b289aefdd860c1a100eab73661
# Successfully built apyori
# Installing collected packages: apyori
# Successfully installed apyori-1.1.2

# %%
import pandas as pd                 # Para la manipulación y análisis de los datos
import numpy as np                  # Para crear vectores y matrices n dimensionales
import matplotlib.pyplot as plt     # Para la generación de gráficas a partir de los datos
from apyori import apriori

# %% [markdown]
# #### **2) Importar los datos**

# %% [markdown]
# **Mine:**

# %%
DatosTransacciones = pd.read_csv('Datos/TV_Shows.csv', header=None)
DatosTransacciones
# Out:
#                  0              1                   2                 3   \
# 0         Cobra Kai          Lupin          12 Monkeys          Sherlock
# 1              Lost      Jack Ryan           The Flash   Game of thrones
# 2     Sex Education      Dr. House             Kingdom  The Walking Dead
# 3             Ozark  Sex Education         Constantine          Preacher
# 4            Naruto            NaN                 NaN               NaN
# ...             ...            ...                 ...               ...
# 9685      One Piece  The Blacklist  Two and a half men             Lupin
# 9686      One Piece      Mr. Robot          Succession             Ozark
# 9687      Daredevil       Atypical               Heros               NaN
# 9688       Absentia   The Newsroom        The Alienist               NaN
# 9689       Atypical            NaN                 NaN               NaN
#
#                   4                      5                    6       7   \
# 0                NaN                    NaN                  NaN     NaN
# 1     House of Cards             12 Monkeys              Vikings  Fringe
# 2                NaN                    NaN                  NaN     NaN
# 3            Vikings               The Tick                  NaN     NaN
# 4                NaN                    NaN                  NaN     NaN
# ...              ...                    ...                  ...     ...
# 9685            Dark  How I met your mother                  NaN     NaN
# 9686      12 Monkeys                Vikings  The Vampire Diaries     NaN
# 9687             NaN                    NaN                  NaN     NaN
# 9688             NaN                    NaN                  NaN     NaN
# 9689             NaN                    NaN                  NaN     NaN
#
#                  8             9   ...   22   23   24   25   26   27   28  \
# 0               NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1     The Mentalist  The Alienist  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2               NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3               NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4               NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...             ...           ...  ...  ...  ...  ...  ...  ...  ...  ...
# 9685            NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 9686            NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 9687            NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 9688            NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 9689            NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#        29   30   31
# 0     NaN  NaN  NaN
# 1     NaN  NaN  NaN
# 2     NaN  NaN  NaN
# 3     NaN  NaN  NaN
# 4     NaN  NaN  NaN
# ...   ...  ...  ...
# 9685  NaN  NaN  NaN
# 9686  NaN  NaN  NaN
# 9687  NaN  NaN  NaN
# 9688  NaN  NaN  NaN
# 9689  NaN  NaN  NaN
#
# [9690 rows x 32 columns]

# %%
#Profesor
DatosTransacciones = pd.read_csv('Datos/store_data.csv')
DatosTransacciones
# Out:
#               shrimp            almonds      avocado    vegetables mix  \
# 0            burgers          meatballs         eggs               NaN
# 1            chutney                NaN          NaN               NaN
# 2             turkey            avocado          NaN               NaN
# 3      mineral water               milk   energy bar  whole wheat rice
# 4     low fat yogurt                NaN          NaN               NaN
# ...              ...                ...          ...               ...
# 7495          butter         light mayo  fresh bread               NaN
# 7496         burgers  frozen vegetables         eggs      french fries
# 7497         chicken                NaN          NaN               NaN
# 7498        escalope          green tea          NaN               NaN
# 7499            eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#      green grapes whole weat flour yams cottage cheese energy drink  \
# 0             NaN              NaN  NaN            NaN          NaN
# 1             NaN              NaN  NaN            NaN          NaN
# 2             NaN              NaN  NaN            NaN          NaN
# 3       green tea              NaN  NaN            NaN          NaN
# 4             NaN              NaN  NaN            NaN          NaN
# ...           ...              ...  ...            ...          ...
# 7495          NaN              NaN  NaN            NaN          NaN
# 7496    magazines        green tea  NaN            NaN          NaN
# 7497          NaN              NaN  NaN            NaN          NaN
# 7498          NaN              NaN  NaN            NaN          NaN
# 7499          NaN              NaN  NaN            NaN          NaN
#
#      tomato juice low fat yogurt green tea honey salad mineral water salmon  \
# 0             NaN            NaN       NaN   NaN   NaN           NaN    NaN
# 1             NaN            NaN       NaN   NaN   NaN           NaN    NaN
# 2             NaN            NaN       NaN   NaN   NaN           NaN    NaN
# 3             NaN            NaN       NaN   NaN   NaN           NaN    NaN
# 4             NaN            NaN       NaN   NaN   NaN           NaN    NaN
# ...           ...            ...       ...   ...   ...           ...    ...
# 7495          NaN            NaN       NaN   NaN   NaN           NaN    NaN
# 7496          NaN            NaN       NaN   NaN   NaN           NaN    NaN
# 7497          NaN            NaN       NaN   NaN   NaN           NaN    NaN
# 7498          NaN            NaN       NaN   NaN   NaN           NaN    NaN
# 7499          NaN            NaN       NaN   NaN   NaN           NaN    NaN
#
#      antioxydant juice frozen smoothie spinach  olive oil
# 0                  NaN             NaN     NaN        NaN
# 1                  NaN             NaN     NaN        NaN
# 2                  NaN             NaN     NaN        NaN
# 3                  NaN             NaN     NaN        NaN
# 4                  NaN             NaN     NaN        NaN
# ...                ...             ...     ...        ...
# 7495               NaN             NaN     NaN        NaN
# 7496               NaN             NaN     NaN        NaN
# 7497               NaN             NaN     NaN        NaN
# 7498               NaN             NaN     NaN        NaN
# 7499               NaN             NaN     NaN        NaN
#
# [7500 rows x 20 columns]

# %% [markdown]
# **Observaciones:**
#
# 1) Se observa que el encabezado es la primera transacción.
#
# 2) NaN indica que esa película no fue rentada o comprada en esa transacción.

# %%
#Profesor
DatosTransacciones = pd.read_csv('Datos/store_data.csv', header=None)
DatosTransacciones.head(5)
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# 0  low fat yogurt  green tea  honey  salad  mineral water  salmon
# 1             NaN        NaN    NaN    NaN            NaN     NaN
# 2             NaN        NaN    NaN    NaN            NaN     NaN
# 3             NaN        NaN    NaN    NaN            NaN     NaN
# 4             NaN        NaN    NaN    NaN            NaN     NaN
#
#                   16               17       18         19
# 0  antioxydant juice  frozen smoothie  spinach  olive oil
# 1                NaN              NaN      NaN        NaN
# 2                NaN              NaN      NaN        NaN
# 3                NaN              NaN      NaN        NaN
# 4                NaN              NaN      NaN        NaN

# %% [markdown]
# #### **3) Procesamiento de los datos**
#
# **Exploración**
#
# Antes de ejecutar el algoritmo es recomendable observar la distribución de la frecuencia de los elementos.

# %%
#Se incluyen todas las transacciones en una sola lista
Transacciones = DatosTransacciones.values.reshape(-1).tolist() #-1 significa 'dimensión desconocida'

#Se crea una matriz (dataframe) usando la lista y se incluye una columna 'Frecuencia'
Lista = pd.DataFrame(Transacciones)
Lista['Frecuencia'] = 1

#Se agrupa los elementos
Lista = Lista.groupby(by=[0], as_index=False).count().sort_values(by=['Frecuencia'], ascending=True) #Conteo
Lista['Porcentaje'] = (Lista['Frecuencia'] / Lista['Frecuencia'].sum()) #Porcentaje
Lista = Lista.rename(columns={0 : 'Item'})

#Se muestra la lista
Lista
# Out:
#                    Item  Frecuencia  Porcentaje
# 58            Iron Fist           4    0.000094
# 48   His Dark Materials           4    0.000094
# 41           Good Omens           6    0.000140
# 114           Teen Wolf           7    0.000164
# 101         Sneaky Pete           8    0.000187
# ..                  ...         ...         ...
# 9              Atypical        1356    0.031703
# 80          Outer Banks        1696    0.039652
# 147  Two and a half men        1779    0.041593
# 82                Ozark        1877    0.043884
# 97        Sex Education        2477    0.057912
#
# [156 rows x 3 columns]

# %%
# Se genera un gráfico de barras
plt.figure(figsize=(16,20), dpi=300)
plt.ylabel('Item')
plt.xlabel('Frecuencia')
plt.barh(Lista['Item'], width=Lista['Frecuencia'], color='blue')
plt.show()

# %%
#Se crea una lista de listas a partir del dataframe y se remueven los 'NaN'
#level=0 especifica desde el primer índice
TransaccionesLista = DatosTransacciones.stack().groupby(level=0).apply(list).tolist()
TransaccionesLista
# Out:
# [['Cobra Kai', 'Lupin', '12 Monkeys', 'Sherlock'],
#  ['Lost',
#   'Jack Ryan',
#   'The Flash',
#   'Game of thrones',
#   'House of Cards',
#   '12 Monkeys',
#   'Vikings',
#   'Fringe',
#   'The Mentalist',
#   'The Alienist',
#   'Big Little Lies',
#   'Chernobyl'],
#  ['Sex Education', 'Dr. House', 'Kingdom', 'The Walking Dead'],
#  ['Ozark', 'Sex Education', 'Constantine', 'Preacher', 'Vikings', 'The Tick'],
#  ['Naruto'],
#  ['Sex Education'],
#  ['Locke & Key'],
#  ['Lupin'],
#  ['Fringe', 'Shooter', 'How to get away with murder'],
#  ['Queen of the South', 'Better Call Saul', 'Peaky Blinders'],
#  ['Sex Education'],
#  ['Atypical', 'Stranger Things', 'Homeland', 'Brooklyn Nine Nine'],
#  ['Daredevil', 'Atypical', 'The Walking Dead', 'The Witcher'],
#  ['One Piece', 'Queen of the South'],
#  ['Demon Slayer',
#   'Atypical',
#   'Stranger Things',
#   'Absentia',
#   'The Alienist',
#   'Chernobyl'],
#  ['Queen of the South',
#   'The Blacklist',
#   'Succession',
#   'Sex Education',
#   'Berlin Station',
#   'Atypical',
#   'Two and a half men',
#   'Kingdom',
#   'Orphan Black',
#   'Shooter',
#   'Stranger Things',
#   'The Mentalist',
#   'Absentia',
#   'Banshee',
#   'Designated Survivor'],
#  ['Daredevil',
#   'Lost',
#   'The Boys',
#   'Family Guy',
#   'The man in the high castle',
#   'Dr. House',
#   'Only Murders in the building',
#   'Ragnarok',
#   'Chernobyl',
#   'How I met your mother'],
#  ['Sex Education',
#   'Two and a half men',
#   'Only Murders in the building',
#   'Perception',
#   'Lucifer'],
#  ['Preacher',
#   'Only Murders in the building',
#   'Absentia',
#   'Spartacus',
#   'Big Little Lies',
#   'Dark'],
#  ['Lost', 'Gotham'],
#  ['Spartacus', 'Perception'],
#  ['Absentia'],
#  ['Into the night',
#   'Demon Slayer',
#   'Ozark',
#   'Constantine',
#   'Kingdom',
#   'Outer Banks'],
#  ['Hanna',
#   'Demon Slayer',
#   'Ozark',
#   'Sex Education',
#   'Berlin Station',
#   'The Walking Dead',
#   'Outer Banks',
#   'Banshee'],
#  ['Daredevil',
#   'The Boys',
#   'Alice in Borderland',
#   'Preacher',
#   'The Outsider',
#   'How to get away with murder',
#   'Spartacus',
#   'The Alienist',
#   'Chernobyl'],
#  ['12 Monkeys', 'Dark', 'How I met your mother'],
#  ['Doctor Who'],
#  ['Doctor Who', 'Mare of Easttown'],
#  ['Sex Education',
#   'Outer Banks',
#   'Brooklyn Nine Nine',
#   'How I met your mother'],
#  ['Arrow',
#   'Into the night',
#   'Queen of the South',
#   'Ozark',
#   'Sex Education',
#   'Peaky Blinders'],
#  ['The Flash', 'The Wire', 'Kingdom'],
#  ['The Blacklist', 'Ozark', 'You'],
#  ['Absentia'],
#  ['Cobra Kai',
#   'Succession',
#   'Sex Education',
#   'Jack Ryan',
#   'Atypical',
#   'Two and a half men',
#   'House of Cards',
#   'Sopranos',
#   'Nine Perfect Strangers',
#   'Absentia'],
#  ['Outer Banks'],
#  ['Demon Slayer', 'Berlin Station', 'Two and a half men', 'Shadow and Bone'],
#  ['Family Guy'],
#  ['Arrow', 'Ozark', 'Sex Education', 'Deception'],
#  ['Upload', 'The Walking Dead', 'Lupin', 'X-Files', 'Archer'],
#  ['The Outsider', 'Outer Banks'],
#  ['Daredevil', 'Jack Ryan', 'Outer Banks'],
#  ['One Piece',
#   'Sex Education',
#   'Berlin Station',
#   'Dr. House',
#   '12 Monkeys',
#   'Sherlock',
#   'How I met your mother'],
#  ['Mirzapur'],
#  ['The Blacklist', 'Rick And Morty', 'Family Guy'],
#  ['Kingdom', 'Rome'],
#  ['The Walking Dead', 'Designated Survivor', 'Goliath'],
#  ['Cobra Kai',
#   'Ozark',
#   'Sex Education',
#   'Jack Ryan',
#   'Atypical',
#   'Family Guy',
#   'Preacher',
#   'The Walking Dead',
#   'X-Files',
#   'Only Murders in the building',
#   'Archer',
#   'Banshee',
#   'Perception',
#   'Bojack Horseman',
#   'Chernobyl',
#   'How I met your mother'],
#  ['Ozark', 'Two and a half men'],
#  ['Succession', 'Ozark'],
#  ['The Stranger',
#   'Lost',
#   'Cobra Kai',
#   'The Blacklist',
#   'Mr. Robot',
#   'Ozark',
#   'Berlin Station',
#   'House of Cards',
#   'Only Murders in the building',
#   'Perception'],
#  ['The Stranger',
#   'Queen of the South',
#   'Demon Slayer',
#   'Rick And Morty',
#   'Ozark',
#   'Sex Education',
#   'Family Guy',
#   'The Originals',
#   'Doctor Who',
#   'Dr. House',
#   'How to get away with murder'],
#  ['The Blacklist',
#   'Demon Slayer',
#   'Ozark',
#   'Outer Banks',
#   'Dark',
#   'The Newsroom'],
#  ['Perception', 'Big Little Lies', 'Chernobyl'],
#  ['Alice in Borderland', 'The Walking Dead', 'How I met your mother'],
#  ['Cobra Kai',
#   'Succession',
#   'Emily in Paris',
#   '12 Monkeys',
#   'Dark',
#   'Chernobyl'],
#  ['Demon Slayer'],
#  ['The Walking Dead', 'Vikings', 'Dark', 'Banshee', 'Lucifer'],
#  ['Mare of Easttown'],
#  ['Lost', 'Ozark', 'Deception', 'Doctor Who', 'The Witcher', 'The Mentalist'],
#  ['Sex Education', 'Haven'],
#  ['Jack Ryan', 'Family Guy', 'Sherlock', 'Archer', 'Banshee'],
#  ['The Blacklist', 'The Night Manager'],
#  ['Supernatural'],
#  ['Sex Education',
#   'Constantine',
#   'Atypical',
#   'Family Guy',
#   'Dr Stone',
#   'The White Lotus'],
#  ['Better Call Saul',
#   'Sex Education',
#   'The Walking Dead',
#   'Stranger Things',
#   'Outer Banks',
#   'Mare of Easttown',
#   'The Alienist',
#   'Brooklyn Nine Nine',
#   'Big Little Lies',
#   'Peaky Blinders',
#   'Lucifer'],
#  ['White Collar', 'Outer Banks', 'Hunters', 'Chernobyl'],
#  ['Queen of the South', 'Designated Survivor'],
#  ['Cobra Kai', 'Ozark', 'Deception', 'Vikings'],
#  ['Mr. Robot', 'White Collar', 'Outer Banks'],
#  ['Breaking Bad',
#   'The Wire',
#   'Vikings',
#   'The Witcher',
#   'Outer Banks',
#   'The Mentalist',
#   'The Night Manager',
#   'Lucifer'],
#  ['Ozark'],
#  ['Absentia'],
#  ['Dark'],
#  ['Hanna',
#   'The Wire',
#   'The Blacklist',
#   'Sex Education',
#   'The Outsider',
#   'How to get away with murder',
#   'Perception'],
#  ['Hanna', 'The Stranger', 'Kingdom', 'Only Murders in the building'],
#  ['Stranger Things', 'Outer Banks'],
#  ['Lucifer'],
#  ['Shooter', 'Rome', 'How I met your mother', 'Supernatural'],
#  ['Mr. Robot', 'Ozark', 'Atypical', 'Preacher', 'Two and a half men'],
#  ['Sex Education', 'Dr. House', 'Two and a half men', 'The Mentalist'],
#  ['Outer Banks'],
#  ['The Blacklist', 'Atypical', 'Archer', 'How I met your mother'],
#  ['Outer Banks'],
#  ['Archer', 'Mare of Easttown', 'Dark'],
#  ['Berlin Station',
#   'Alice in Borderland',
#   'Mare of Easttown',
#   'The Mentalist'],
#  ['Daredevil',
#   'The Stranger',
#   'Demon Slayer',
#   'The Boys',
#   'Rick And Morty',
#   'Mr. Robot',
#   'Succession',
#   'Ozark',
#   'Sex Education',
#   'Berlin Station',
#   'Family Guy',
#   'The Outsider',
#   'Two and a half men',
#   '12 Monkeys',
#   'Sopranos',
#   'Sherlock',
#   'Stranger Things',
#   'Absentia',
#   'You',
#   'Big Little Lies'],
#  ['Absentia', 'Lucifer'],
#  ['Arrow',
#   'Sex Education',
#   'Berlin Station',
#   'Jack Ryan',
#   'Constantine',
#   'Travellers',
#   'Atypical',
#   "Grey's Anatomy",
#   'Kingdom',
#   'The Walking Dead',
#   'The Mentalist',
#   'Shadow and Bone',
#   'Lucifer'],
#  ['Absentia'],
#  ['Inhumans',
#   'The Blacklist',
#   'Demon Slayer',
#   'The Boys',
#   'Sex Education',
#   'Jack Ryan',
#   'Family Guy',
#   'Deception',
#   'Punisher'],
#  ['Daredevil',
#   'The Stranger',
#   'Cobra Kai',
#   'Demon Slayer',
#   'Atypical',
#   'Prison Break',
#   'Deception',
#   'Dr. House',
#   'Two and a half men',
#   'The Walking Dead',
#   'Banshee',
#   'Spartacus',
#   'How I met your mother'],
#  ['Mr. Robot', 'Ozark', 'Travellers', 'Two and a half men', 'The Innocent'],
#  ['Sex Education',
#   'Berlin Station',
#   'Kingdom',
#   'The Walking Dead',
#   'Mindhunter',
#   'Outer Banks',
#   'How I met your mother'],
#  ['Mr. Robot', '12 Monkeys', 'Stranger Things', 'Outer Banks'],
#  ['The Office', 'Chernobyl'],
#  ['Outer Banks'],
#  ['Atypical', 'Two and a half men', 'The Alienist'],
#  ['Travellers', 'Two and a half men'],
#  ['Two and a half men', 'The Wire', 'Hunters', 'Lucifer'],
#  ['Daredevil',
#   'Sex Education',
#   'Family Guy',
#   'House of Cards',
#   'The Umbrella Academy',
#   'The Mentalist'],
#  ['Daredevil', 'Dark', 'The 100'],
#  ['Teen Wolf'],
#  ['Dr. House', 'The Walking Dead', 'Big Little Lies'],
#  ['The Blacklist'],
#  ['Two and a half men', 'Outer Banks'],
#  ['Emily in Paris', 'Two and a half men'],
#  ['Atypical',
#   'Two and a half men',
#   'Dexter',
#   'Outer Banks',
#   'Absentia',
#   'Spartacus'],
#  ['One Piece',
#   'Cobra Kai',
#   'Mr. Robot',
#   'Sex Education',
#   'Constantine',
#   'Atypical',
#   'Supergirl',
#   '12 Monkeys',
#   'Lost in Space',
#   'Shadow and Bone',
#   'The Night Manager'],
#  ['Cobra Kai',
#   'The Blacklist',
#   'Sex Education',
#   'Berlin Station',
#   'Jack Ryan',
#   'Atypical',
#   'Game of thrones',
#   'Stranger Things',
#   'The Tick'],
#  ['The Stranger',
#   'Demon Slayer',
#   'Sex Education',
#   'Two and a half men',
#   'Kingdom',
#   'The Walking Dead',
#   'Lupin',
#   '12 Monkeys',
#   'Stranger Things',
#   'How I met your mother'],
#  ['Ozark'],
#  ['Hanna',
#   'Rick And Morty',
#   'Ozark',
#   'Sex Education',
#   "Grey's Anatomy",
#   'Dr. House',
#   'Two and a half men',
#   'Kingdom',
#   'The Walking Dead',
#   'Lucifer'],
#  ['Kingdom'],
#  ['The Big Bang Theory', 'Outer Banks', 'Lucifer'],
#  ['His Dark Materials'],
#  ['Absentia'],
#  ['Absentia'],
#  ['The Blacklist',
#   'Ozark',
#   'The Walking Dead',
#   'Banshee',
#   'Spartacus',
#   'Shadow and Bone',
#   'Brooklyn Nine Nine',
#   'Lucifer'],
#  ['Sex Education'],
#  ['One Piece', 'Outer Banks', 'Absentia', 'Westworld'],
#  ['Lost',
#   'Person of Interest',
#   'White Collar',
#   'Dr. House',
#   'Only Murders in the building',
#   'Shadow and Bone'],
#  ['Sex Education', 'Dr. House'],
#  ['Demon Slayer',
#   'The Boys',
#   'Doctor Who',
#   'Two and a half men',
#   'Sopranos',
#   'Absentia',
#   'Euphoria'],
#  ['Two and a half men'],
#  ['Sex Education',
#   'Travellers',
#   'The Flash',
#   'Archer',
#   'Shadow and Bone',
#   'The Night Manager'],
#  ['Sex Education',
#   'Atypical',
#   'Dr. House',
#   'Two and a half men',
#   'The Mentalist',
#   'Banshee',
#   'Designated Survivor',
#   'Brooklyn Nine Nine'],
#  ['Demon Slayer',
#   'Mr. Robot',
#   'Succession',
#   'Ozark',
#   'Deception',
#   'The Walking Dead'],
#  ['Sex Education', 'Outer Banks'],
#  ['12 Monkeys', 'Banshee'],
#  ['The Wire', 'Demon Slayer', 'Ozark', 'Kingdom', 'Sense 8', 'Outer Banks'],
#  ['Lucifer'],
#  ['The Blacklist',
#   'Demon Slayer',
#   'Two and a half men',
#   'Archer',
#   'The Mentalist',
#   'The Night Manager'],
#  ['Mr. Robot'],
#  ['Sex Education', '24', 'The Mentalist'],
#  ['Daredevil',
#   'Demon Slayer',
#   'Jack Ryan',
#   'Outer Banks',
#   'Absentia',
#   'Haven',
#   'Lucifer'],
#  ['Two and a half men', 'Outer Banks'],
#  ['Emily in Paris', 'Dr. House', 'Mare of Easttown'],
#  ['One Piece', 'Mr. Robot'],
#  ['Banshee', 'The Night Manager'],
#  ['Better Call Saul'],
#  ['Daredevil', 'Two and a half men', 'Outer Banks', 'Shadow and Bone'],
#  ['Mr. Robot', 'Atypical', 'Emily in Paris', 'Game of thrones'],
#  ['Hanna',
#   'The Stranger',
#   'One Piece',
#   'Cobra Kai',
#   'The Blacklist',
#   'Demon Slayer',
#   'Mr. Robot',
#   'Person of Interest',
#   'Ozark',
#   'Sex Education',
#   'Travellers',
#   'Emily in Paris',
#   'Alice in Borderland',
#   'Deception',
#   'Sense 8',
#   'House of Cards'],
#  ['Family Guy', 'Deception', 'Game of thrones', 'The Expanse'],
#  ['Arrow',
#   'Cobra Kai',
#   'The Blacklist',
#   'Sex Education',
#   'Atypical',
#   'Family Guy',
#   'Outer Banks'],
#  ['Outer Banks'],
#  ['The Walking Dead', 'Outer Banks', 'Brooklyn Nine Nine'],
#  ['Arrow',
#   'Breaking Bad',
#   'Two and a half men',
#   'The Wire',
#   'The Mentalist',
#   'Absentia',
#   'Banshee',
#   'Spartacus',
#   'Shadow and Bone',
#   'Brooklyn Nine Nine'],
#  ['Two and a half men', 'Kingdom', 'Outer Banks'],
#  ['The Wire',
#   'One Piece',
#   'The Wilds',
#   'The Blacklist',
#   'The Boys',
#   'Rick And Morty',
#   'Ozark',
#   'Sex Education',
#   'Deception',
#   'Lupin',
#   'Shadow and Bone',
#   'Perception',
#   'His Dark Materials',
#   'Dark'],
#  ['Atypical', '12 Monkeys', 'Stranger Things', 'The Alienist'],
#  ['Daredevil',
#   'The Stranger',
#   'Queen of the South',
#   'Cobra Kai',
#   'The Blacklist',
#   'Mr. Robot',
#   'Succession',
#   'Person of Interest',
#   'Ozark',
#   'Sex Education',
#   'Berlin Station',
#   'Jack Ryan',
#   'Atypical',
#   'Doctor Who',
#   'Dr. House'],
#  ['The Umbrella Academy', 'Stranger Things'],
#  ['Sex Education'],
#  ['Queen of the South',
#   'Mr. Robot',
#   'Person of Interest',
#   'Ozark',
#   'Sex Education',
#   'Berlin Station',
#   'Two and a half men',
#   'Kingdom',
#   'Dark',
#   'Banshee',
#   'Peaky Blinders'],
#  ['Cobra Kai', 'Sex Education', 'Jack Ryan', 'Travellers', 'The Walking Dead'],
#  ['The Blacklist', 'Sex Education', '12 Monkeys', 'Vikings'],
#  ['Family Guy', 'The Innocent'],
#  ['Two and a half men'],
#  ['Lost in Space',
#   'Stranger Things',
#   'The Mentalist',
#   'How I met your mother'],
#  ['Daredevil', 'Kingdom', 'Sense 8', 'Archer', 'Hunters'],
#  ['Succession', 'Ozark', 'Game of thrones'],
#  ['Sex Education',
#   'Atypical',
#   'The Flash',
#   'Two and a half men',
#   'Stranger Things'],
#  ['Sex Education',
#   'Constantine',
#   'Atypical',
#   '12 Monkeys',
#   'How I met your mother'],
#  ['Hanna',
#   'Demon Slayer',
#   'Mr. Robot',
#   'Jack Ryan',
#   'Atypical',
#   'White Collar',
#   'The Wire',
#   'The Walking Dead',
#   'Dexter',
#   'Spartacus',
#   'Hunters'],
#  ['The Wilds',
#   'Ozark',
#   'Better Call Saul',
#   'The Witcher',
#   'The Umbrella Academy',
#   'Archer',
#   'Stranger Things',
#   'Locke & Key'],
#  ['The Walking Dead', 'Archer', 'Spartacus'],
#  ['Cobra Kai',
#   'Demon Slayer',
#   'The Boys',
#   'Ozark',
#   'Constantine',
#   'Travellers',
#   'Atypical',
#   'Dr. House',
#   'Game of thrones',
#   'Only Murders in the building',
#   'Vikings',
#   'Sons of Anarchy',
#   'Perception',
#   'Hunters'],
#  ['One Piece',
#   'Mr. Robot',
#   'Person of Interest',
#   'Sex Education',
#   'Deception',
#   'Two and a half men',
#   'Mindhunter',
#   'Perception',
#   'The Expanse'],
#  ['Lost', 'Sons of Anarchy'],
#  ['Absentia'],
#  ['The Walking Dead'],
#  ['Better Call Saul', 'Constantine', 'Lupin', 'Absentia'],
#  ['Outer Banks'],
#  ['Daredevil',
#   'Two and a half men',
#   'Outer Banks',
#   'Absentia',
#   'Brooklyn Nine Nine',
#   'Lucifer'],
#  ['Demon Slayer',
#   'Sex Education',
#   'Dr. House',
#   'The Wire',
#   'Game of thrones',
#   'Inside Job',
#   'Punisher',
#   'Stranger Things',
#   'The Mentalist',
#   'The Expanse'],
#  ['Shadow and Bone'],
#  ['The Outsider', 'Archer', 'Spartacus'],
#  ['Dark'],
#  ['Jack Ryan',
#   'Doctor Who',
#   'The Walking Dead',
#   'Banshee',
#   'Spartacus',
#   'Chernobyl'],
#  ['Travellers', 'Black Clover'],
#  ['Archer'],
#  ['The Blacklist', 'Family Guy', 'The Nevers'],
#  ['The Blacklist', "Grey's Anatomy", 'Two and a half men', 'Shadow and Bone'],
#  ['Daredevil', 'Heros', 'Preacher', 'Absentia'],
#  ['Daredevil',
#   'Mr. Robot',
#   'Ozark',
#   'Sex Education',
#   'Only Murders in the building',
#   'Sopranos',
#   'Designated Survivor',
#   'How I met your mother'],
#  ['Ozark', 'Sex Education', 'The Wire', 'The Alienist'],
#  ['The Stranger',
#   'The Blacklist',
#   'Demon Slayer',
#   'Ozark',
#   'Atypical',
#   'The Walking Dead',
#   'Dark',
#   'Locke & Key'],
#  ['Archer'],
#  ['Hunters'],
#  ['Arrow',
#   'The Blacklist',
#   'Nine Perfect Strangers',
#   'Outer Banks',
#   'Absentia'],
#  ['Doctor Who'],
#  ['Cobra Kai',
#   'Atypical',
#   'White Collar',
#   'The Walking Dead',
#   'Orphan Black',
#   'Archer',
#   'Elite'],
#  ['Dr. House',
#   'The Walking Dead',
#   'Dark',
#   'Absentia',
#   'Banshee',
#   'Shadow and Bone',
#   'Dark',
#   'How I met your mother'],
#  ['Person of Interest'],
#  ['The Blacklist',
#   'Sex Education',
#   'Atypical',
#   'Two and a half men',
#   'The Walking Dead',
#   'Archer',
#   'Designated Survivor'],
#  ['Only Murders in the building', 'The Night Manager'],
#  ['One Piece', 'Stranger Things', 'Dark'],
#  ['Ozark', 'Shadow and Bone'],
#  ['Kingdom'],
#  ['The Blacklist',
#   'Family Guy',
#   'White Collar',
#   'The Innocent',
#   'House of Cards',
#   'Only Murders in the building',
#   'How to get away with murder',
#   'The Night Manager'],
#  ['One Piece',
#   'Ozark',
#   'Atypical',
#   'The Wire',
#   'Dark',
#   'Chernobyl',
#   'Lucifer'],
#  ['Hunters', 'Love Death Robots', 'Big Little Lies', 'Chernobyl'],
#  ['The Stranger', 'Rick And Morty', 'Deception', 'Archer', 'The IT Crowd'],
#  ['One Piece', 'The Wilds', 'Cobra Kai', 'Sex Education', 'Banshee'],
#  ['Better Call Saul', 'Stranger Things'],
#  ['The Blacklist',
#   'Mr. Robot',
#   'Sex Education',
#   'Jack Ryan',
#   'Atypical',
#   'Deception',
#   'Dr. House'],
#  ['The Blacklist',
#   'Sex Education',
#   'Two and a half men',
#   'Sherlock',
#   'How to get away with murder',
#   'Brooklyn Nine Nine'],
#  ['Daredevil',
#   'Sex Education',
#   'Two and a half men',
#   'Outer Banks',
#   'How to get away with murder',
#   'Banshee',
#   'Spartacus',
#   'Outlander',
#   'The Night Manager'],
#  ['Demon Slayer'],
#  ['The Flash', 'The Walking Dead', 'Suits', 'Peaky Blinders'],
#  ['Ozark', 'Atypical', 'Family Guy', 'How I met your mother'],
#  ['Mr. Robot', 'Ozark', 'Friends', 'Suits', 'Lucifer'],
#  ['Daredevil',
#   'Arrow',
#   'Queen of the South',
#   'Mr. Robot',
#   'White Collar',
#   'The Umbrella Academy',
#   'Outer Banks'],
#  ['One Piece', 'Queen of the South', 'Better Call Saul', 'The Walking Dead'],
#  ['Mr. Robot', 'Ozark', 'Sex Education', 'The Big Bang Theory', 'Dark'],
#  ['Ozark',
#   'Preacher',
#   'The Wire',
#   'The Nevers',
#   'Archer',
#   'Stranger Things',
#   'Outer Banks',
#   'The Mentalist',
#   'Absentia',
#   'Locke & Key',
#   'The IT Crowd'],
#  ['Sex Education'],
#  ['Ozark',
#   'Sex Education',
#   'The Walking Dead',
#   'Game of thrones',
#   '12 Monkeys',
#   'Black Clover',
#   'Banshee',
#   'Shadow and Bone'],
#  ['The Stranger',
#   'Rick And Morty',
#   'Mr. Robot',
#   'Person of Interest',
#   'Ozark',
#   'Sex Education',
#   'Jack Ryan',
#   'The Outsider',
#   'Dr. House',
#   '12 Monkeys',
#   'The Big Bang Theory',
#   'How I met your mother'],
#  ['Daredevil',
#   'Demon Slayer',
#   'Two and a half men',
#   'The Walking Dead',
#   'Outer Banks',
#   'The Mentalist',
#   'Absentia',
#   'How to get away with murder',
#   'The Night Manager',
#   'Big Little Lies'],
#  ['Cobra Kai',
#   'Constantine',
#   'Atypical',
#   'White Collar',
#   'Deception',
#   'Supergirl',
#   'Mirzapur',
#   'The Vampire Diaries',
#   'Spartacus'],
#  ['How I met your mother'],
#  ['Daredevil', 'The Wire', 'The Blacklist', 'Preacher'],
#  ['The Blacklist', 'Travellers', 'Kingdom', 'Game of thrones'],
#  ['Daredevil',
#   'Ozark',
#   'Constantine',
#   'Dr. House',
#   'The Walking Dead',
#   'Chernobyl'],
#  ['Outer Banks', 'Ragnarok'],
#  ['Atypical', 'Stranger Things', 'Absentia', 'Chernobyl'],
#  ['Daredevil',
#   'Cobra Kai',
#   'Demon Slayer',
#   'Sex Education',
#   'Jack Ryan',
#   'Dr. House',
#   '12 Monkeys',
#   'How I met your mother'],
#  ['Emily in Paris'],
#  ['Demon Slayer', 'Mr. Robot', 'Mirzapur', 'The Mentalist', 'Peaky Blinders'],
#  ['Inhumans',
#   'Cobra Kai',
#   'Ozark',
#   'Jack Ryan',
#   "The Queen's Gambit",
#   'Lupin',
#   'Schitts Creek'],
#  ['The Mentalist'],
#  ['Preacher'],
#  ['Arrow',
#   'The Wire',
#   'Sex Education',
#   'Constantine',
#   'Travellers',
#   'Family Guy',
#   'Alice in Borderland',
#   'Two and a half men',
#   'Outer Banks',
#   'The Mentalist'],
#  ['Hanna',
#   'Inhumans',
#   'Demon Slayer',
#   'Sex Education',
#   'Atypical',
#   'Emily in Paris',
#   'Preacher',
#   'Deception',
#   'Doctor Who',
#   'Kingdom',
#   'The Walking Dead',
#   'Sacred Games',
#   'Stranger Things',
#   'Outer Banks',
#   'The Mentalist',
#   'The White Lotus'],
#  ['The Night Manager'],
#  ['Hanna', 'Two and a half men', 'Shadow and Bone'],
#  ['Archer'],
#  ['Lost',
#   'The Blacklist',
#   'Person of Interest',
#   'Ozark',
#   'Sex Education',
#   'Jack Ryan',
#   'The Outsider',
#   'Fringe',
#   'How I met your mother',
#   'Lucifer'],
#  ['Mare of Easttown'],
#  ['Lost', 'Demon Slayer', 'Ozark', 'Sex Education', 'Jack Ryan', 'Sense 8'],
#  ['Jack Ryan'],
#  ['Iron Fist'],
#  ['Mare of Easttown', 'Haven'],
#  ['The Stranger', 'Banshee', 'Shadow and Bone'],
#  ['The man in the high castle', 'Two and a half men', 'Kingdom'],
#  ['Better Call Saul'],
#  ['One Piece', 'Ozark', 'Sex Education', 'Sacred Games'],
#  ['Two and a half men'],
#  ['Two and a half men', 'Dark'],
#  ['Outer Banks'],
#  ['Love Death Robots'],
#  ['Succession'],
#  ['Sex Education', 'Jack Ryan', 'Preacher', 'Lucifer'],
#  ['Mindhunter', 'Big Little Lies', 'Startup'],
#  ["The Handmaid's Tale"],
#  ['The Blacklist',
#   'Jack Ryan',
#   'Alice in Borderland',
#   'Two and a half men',
#   'Outer Banks'],
#  ['The Blacklist', 'Ozark', 'Atypical'],
#  ['White Collar', 'Kingdom', 'Sopranos', 'Archer', 'Outer Banks', 'Hunters'],
#  ['Hanna', 'The Stranger', 'The Outsider', 'Two and a half men'],
#  ['Two and a half men', 'Stranger Things'],
#  ['Atypical',
#   'Emily in Paris',
#   'The Mentalist',
#   'Perception',
#   'Bojack Horseman'],
#  ['Daredevil'],
#  ['Demon Slayer'],
#  ['Into the night',
#   'Atypical',
#   'Two and a half men',
#   'The Walking Dead',
#   '12 Monkeys',
#   'Stranger Things',
#   'Outer Banks',
#   'The Mentalist',
#   'Absentia'],
#  ['Demon Slayer',
#   'Sex Education',
#   'Prison Break',
#   'Black Clover',
#   'Mare of Easttown',
#   'The Mentalist',
#   'The Night Manager'],
#  ['Berlin Station', 'The Outsider', 'Kingdom', 'Dark', "The Queen's Gambit"],
#  ['Hanna', 'Sex Education', 'Two and a half men', 'The Innocent'],
#  ['Queen of the South',
#   'The Blacklist',
#   'Sex Education',
#   '12 Monkeys',
#   'Outer Banks',
#   'Dark'],
#  ['Stranger Things', 'Designated Survivor'],
#  ['Daredevil',
#   'Constantine',
#   'Dr. House',
#   'Two and a half men',
#   'Outer Banks',
#   'Dark',
#   'Locke & Key',
#   'How to get away with murder',
#   'Chernobyl'],
#  ['Outer Banks', 'Designated Survivor', 'Lucifer'],
#  ['Outer Banks'],
#  ['Spartacus'],
#  ['Mare of Easttown'],
#  ['Queen of the South', "Grey's Anatomy", 'Dark'],
#  ['Queen of the South', 'Mr. Robot', 'Big Little Lies'],
#  ['Ozark',
#   'Sex Education',
#   'Supergirl',
#   'The Wire',
#   'Lost in Space',
#   'Banshee'],
#  ['Daredevil', 'Two and a half men', 'Outer Banks'],
#  ['Euphoria'],
#  ['Absentia', 'Brooklyn Nine Nine'],
#  ['Ozark', 'The Mentalist', 'How to get away with murder', 'Chernobyl'],
#  ['Rome'],
#  ['Elementary', 'Ozark', 'Deception', 'Dark'],
#  ['Demon Slayer', 'Travellers', 'Outer Banks'],
#  ['Queen of the South', 'Mr. Robot'],
#  ['Absentia', 'Lucifer'],
#  ['Chernobyl'],
#  ['Outer Banks', 'The Alienist'],
#  ['Prison Break', 'Upload'],
#  ['Outer Banks', 'The Office'],
#  ['Cobra Kai', 'Sex Education', 'Squid Game'],
#  ['Mirzapur', 'Banshee', 'The Wheel of Time'],
#  ['Ozark',
#   'Sex Education',
#   'Travellers',
#   'Atypical',
#   'Preacher',
#   'Dr. House',
#   'Two and a half men',
#   'Kingdom',
#   'Outer Banks',
#   'The Mentalist',
#   'Absentia',
#   'Locke & Key',
#   'Banshee',
#   'Shadow and Bone',
#   'Lucifer'],
#  ['Atypical', 'White Collar', 'Two and a half men'],
#  ['Daredevil', 'Alice in Borderland', 'Lost in Space'],
#  ['The Wire', 'Banshee', 'Lucifer'],
#  ['Queen of the South',
#   'Lost',
#   'Rick And Morty',
#   'The Walking Dead',
#   'Big Little Lies'],
#  ['Riverdale',
#   'The 100',
#   'The Newsroom',
#   'Banshee',
#   'Hunters',
#   'Chernobyl',
#   'The Tick',
#   'Lucifer'],
#  ['Arrow', 'One Piece', 'Lucifer'],
#  ['Ozark'],
#  ['Sex Education', 'Dark'],
#  ['Rome'],
#  ['The Blacklist', 'Demon Slayer', 'Atypical'],
#  ['Archer', 'Big Little Lies'],
#  ['Demon Slayer', 'Stranger Things'],
#  ['The Blacklist', 'Demon Slayer', 'Outer Banks', 'Rome'],
#  ['Ozark',
#   'Sex Education',
#   'The man in the high castle',
#   'Kingdom',
#   'Lupin',
#   'The Innocent',
#   'Shooter'],
#  ['Lost'],
#  ['Two and a half men', 'Kingdom', 'Absentia'],
#  ['Cobra Kai',
#   'Mr. Robot',
#   'Better Call Saul',
#   'Atypical',
#   'Alice in Borderland',
#   'Two and a half men',
#   'The Wire',
#   'Kingdom',
#   'Mirzapur'],
#  ['Dark'],
#  ['Ozark',
#   'Sex Education',
#   'Deception',
#   'Lupin',
#   'X-Files',
#   'Nine Perfect Strangers',
#   'How to get away with murder',
#   'Banshee',
#   'Peaky Blinders'],
#  ['Daredevil', 'Ozark', 'Alice in Borderland', 'Sopranos', 'The Mentalist'],
#  ['Sex Education',
#   'Berlin Station',
#   'Atypical',
#   'Kingdom',
#   'Stranger Things',
#   'Outer Banks',
#   'The Mentalist',
#   'Banshee',
#   'How I met your mother'],
#  ['Sex Education', 'Haven', 'How I met your mother'],
#  ['Hanna',
#   'One Piece',
#   'Demon Slayer',
#   'Mr. Robot',
#   'Ozark',
#   'Sex Education',
#   'Travellers',
#   'Atypical',
#   'Preacher',
#   'Two and a half men',
#   'Kingdom',
#   'Outer Banks'],
#  ['Daredevil',
#   'The Blacklist',
#   'Ozark',
#   'Sex Education',
#   'Deception',
#   'Two and a half men',
#   'The Wire',
#   'Kingdom',
#   'Sense 8',
#   'Only Murders in the building',
#   'Vikings'],
#  ['Hanna',
#   'Cobra Kai',
#   'Sex Education',
#   'Dr. House',
#   'Only Murders in the building',
#   'Friends',
#   'Designated Survivor',
#   'How I met your mother'],
#  ['Sex Education'],
#  ['Mr. Robot'],
#  ['Ozark', 'Doctor Who', 'Designated Survivor'],
#  ['The Boys'],
#  ['Sex Education'],
#  ['The Blacklist', 'Lucifer'],
#  ['Hanna',
#   'Ozark',
#   'Sex Education',
#   'Jack Ryan',
#   'Supergirl',
#   'Dr. House',
#   '12 Monkeys',
#   'Homeland',
#   'Dark',
#   'Absentia'],
#  ['Hanna',
#   'The Blacklist',
#   'Mr. Robot',
#   'Sex Education',
#   'Jack Ryan',
#   'Constantine',
#   'Deception',
#   'The Walking Dead',
#   'Dexter',
#   'Homeland',
#   'How I met your mother'],
#  ['Atypical', 'Two and a half men', 'Mare of Easttown'],
#  ['Cobra Kai',
#   'Mr. Robot',
#   'Succession',
#   'Ozark',
#   'Dr. House',
#   'The Wire',
#   'Haven'],
#  ['Cobra Kai',
#   'The Blacklist',
#   'Demon Slayer',
#   'Rick And Morty',
#   'Ozark',
#   'Family Guy',
#   "Grey's Anatomy",
#   'Kingdom',
#   'Mirzapur',
#   'The Big Bang Theory',
#   'Inside Job',
#   'Archer',
#   'How I met your mother',
#   'Lucifer'],
#  ['Arrow',
#   'Cobra Kai',
#   'Travellers',
#   'Atypical',
#   'Preacher',
#   'Two and a half men',
#   'Nine Perfect Strangers',
#   'Goliath',
#   'Chernobyl',
#   'Peaky Blinders'],
#  ['Ozark', 'Kingdom', 'The Vampire Diaries', 'Rome'],
#  ['The Alienist'],
#  ['Ozark',
#   'The man in the high castle',
#   'Only Murders in the building',
#   'Lucifer'],
#  ['Gotham'],
#  ['The Boys', 'Mare of Easttown', 'The Mentalist'],
#  ['Elementary',
#   'The Stranger',
#   'Mr. Robot',
#   'Sex Education',
#   'Travellers',
#   'Kingdom',
#   'The Mentalist'],
#  ['Atypical', 'Stranger Things'],
#  ['Dr. House',
#   'Two and a half men',
#   'Archer',
#   'Absentia',
#   'Riverdale',
#   'Shadow and Bone',
#   'Lucifer'],
#  ['Absentia'],
#  ['Sex Education', 'Deception'],
#  ['Ozark', 'Two and a half men', 'Kingdom'],
#  ['Dark',
#   'Riverdale',
#   'Sneaky Pete',
#   'Shadow and Bone',
#   'Designated Survivor',
#   'Lucifer'],
#  ['Gotham'],
#  ['Daredevil',
#   'Cobra Kai',
#   'The Blacklist',
#   'Sex Education',
#   'Stranger Things',
#   'Brooklyn Nine Nine',
#   'Perception',
#   'How I met your mother'],
#  ['Cobra Kai',
#   'The Blacklist',
#   'Mr. Robot',
#   'Atypical',
#   'Shooter',
#   'Stranger Things',
#   'Outer Banks',
#   'The Good Doctor'],
#  ['The Blacklist', 'Preacher', 'Shadow and Bone'],
#  ['The Alienist', 'Brooklyn Nine Nine'],
#  ['Ozark',
#   'Doctor Who',
#   'Two and a half men',
#   'Stranger Things',
#   'Dark',
#   'Locke & Key'],
#  ['The Witcher', 'Shadow and Bone', 'Designated Survivor'],
#  ['Daredevil', 'Two and a half men', 'The Mentalist'],
#  ['The Walking Dead'],
#  ['Mr. Robot', 'Dr. House', '12 Monkeys', 'Outlander', 'The Night Manager'],
#  ['Outer Banks', 'Dark', 'The 100', 'Locke & Key'],
#  ['The Wire',
#   'One Piece',
#   'Succession',
#   "The Queen's Gambit",
#   'Dr. House',
#   'The Wire',
#   'Game of thrones',
#   'The Innocent',
#   'Dark'],
#  ['Ozark',
#   'Supergirl',
#   'Lost in Space',
#   'Nine Perfect Strangers',
#   'How to get away with murder',
#   'Lucifer'],
#  ['Outer Banks'],
#  ['The Wire'],
#  ['The Blacklist',
#   'Demon Slayer',
#   'Rick And Morty',
#   'The Outsider',
#   'The Wire'],
#  ['Daredevil',
#   'Cobra Kai',
#   'Ozark',
#   'Dr Stone',
#   'Punisher',
#   'Stranger Things',
#   'Perception',
#   'How I met your mother'],
#  ['Hanna',
#   'Into the night',
#   'The Blacklist',
#   'The Boys',
#   'Mr. Robot',
#   'Ozark',
#   'Sex Education',
#   'Deception',
#   'Doctor Who',
#   'The man in the high castle',
#   'The Walking Dead',
#   'Lost in Space',
#   'Mindhunter',
#   'Outer Banks',
#   'Mare of Easttown',
#   'How to get away with murder',
#   'Haven',
#   'Shadow and Bone',
#   'Perception',
#   'Startup'],
#  ['Nine Perfect Strangers', 'The Umbrella Academy', 'Lucifer'],
#  ['The Blacklist',
#   'Demon Slayer',
#   'Sex Education',
#   'The Flash',
#   'Doctor Who',
#   'The Wire',
#   'Mirzapur',
#   'Friends',
#   'The Good Doctor',
#   'Big Little Lies',
#   'How I met your mother'],
#  ['Cobra Kai',
#   'The Blacklist',
#   'Family Guy',
#   'Two and a half men',
#   'The Night Manager',
#   'How I met your mother'],
#  ['Queen of the South', 'The Blacklist', 'Atypical'],
#  ['Outer Banks', 'Dark', 'The 100', 'Locke & Key', 'Chernobyl'],
#  ['One Piece', 'Stranger Things', 'Rome'],
#  ['Lost',
#   'Mr. Robot',
#   'Sex Education',
#   'Atypical',
#   'Kingdom',
#   'The Walking Dead',
#   'Dark',
#   'Designated Survivor',
#   'The Expanse'],
#  ['Cobra Kai',
#   'The Blacklist',
#   'Rick And Morty',
#   'Mr. Robot',
#   'Ozark',
#   'Sex Education',
#   'Berlin Station',
#   'Stranger Things',
#   'South Park',
#   'Big Little Lies',
#   'Chernobyl'],
#  ['Daredevil',
#   'Cobra Kai',
#   'Outer Banks',
#   'The Mentalist',
#   'How to get away with murder',
#   'Chernobyl',
#   'The IT Crowd'],
#  ['Outer Banks'],
#  ['The Blacklist', 'Two and a half men', 'The Walking Dead'],
#  ['One Piece', 'Absentia', 'Ragnarok'],
#  ['Two and a half men', 'Kingdom', 'The Walking Dead', 'Archer', 'Dark'],
#  ['Billions', 'Two and a half men', 'Archer', 'How to get away with murder'],
#  ['Absentia', 'Lucifer'],
#  ['Breaking Bad',
#   'Outer Banks',
#   'Dark',
#   'The 100',
#   'Locke & Key',
#   'Chernobyl'],
#  ['The Office'],
#  ['Cobra Kai',
#   'The Blacklist',
#   'Demon Slayer',
#   'Prison Break',
#   'Doctor Who',
#   '24',
#   'Black Clover',
#   'Archer',
#   'Absentia',
#   'How to get away with murder',
#   'The IT Crowd',
#   'The White Lotus',
#   'Lucifer'],
#  ['Two and a half men', '12 Monkeys', 'How I met your mother'],
#  ['Constantine', 'Designated Survivor'],
#  ['Cobra Kai', 'Ozark', 'Berlin Station', 'Two and a half men'],
#  ["Grey's Anatomy", 'Outer Banks', 'Rome'],
#  ['The Witcher'],
#  ['Daredevil',
#   'Alice in Borderland',
#   'Two and a half men',
#   'Vikings',
#   'The Night Manager'],
#  ['Hanna', 'Mr. Robot', 'Succession', 'Ozark', 'The Wire', 'Absentia'],
#  ['Sex Education',
#   'Family Guy',
#   'Lupin',
#   'Punisher',
#   'Lost in Space',
#   'Stranger Things',
#   'Outer Banks',
#   'Chernobyl'],
#  ['Outer Banks'],
#  ['Inhumans',
#   'Queen of the South',
#   'Demon Slayer',
#   'Better Call Saul',
#   'Sex Education',
#   'The Walking Dead',
#   '12 Monkeys'],
#  ['Daredevil', 'Madmen', 'Dr. House', 'Outer Banks', 'Lucifer'],
#  ['Cobra Kai',
#   'The Blacklist',
#   'Demon Slayer',
#   'Atypical',
#   'The Outsider',
#   'Outer Banks'],
#  ['Hanna',
#   'Demon Slayer',
#   'Succession',
#   'Sex Education',
#   'Jack Ryan',
#   'Atypical',
#   'The Walking Dead',
#   'Fringe',
#   'His Dark Materials'],
#  ['Shooter'],
#  ['House of Cards', 'Outer Banks', 'Squid Game', 'Haven'],
#  ['The Stranger',
#   'Atypical',
#   'Family Guy',
#   'Upload',
#   'Outer Banks',
#   'Peaky Blinders'],
#  ['The Wire',
#   'One Piece',
#   'Mr. Robot',
#   'Ozark',
#   'Atypical',
#   'Preacher',
#   'Two and a half men',
#   'The Wire',
#   'X-Files',
#   'Outer Banks',
#   'Haven',
#   'Chernobyl'],
#  ['Into the night',
#   'The Blacklist',
#   'Demon Slayer',
#   'Mr. Robot',
#   'Ozark',
#   'Jack Ryan',
#   'Travellers',
#   'Atypical',
#   'Invincible',
#   'Locke & Key',
#   'X-Files',
#   '12 Monkeys'],
#  ['Daredevil', 'Stranger Things'],
#  ['Hanna', 'Daredevil', 'Supergirl', '12 Monkeys', 'Brooklyn Nine Nine'],
#  ['Daredevil', 'Stranger Things', 'Rome'],
#  ['White Collar',
#   'Archer',
#   'Absentia',
#   'Designated Survivor',
#   'The Night Manager'],
#  ['Rome'],
#  ['Brooklyn Nine Nine'],
#  ['Arrow',
#   'The Boys',
#   'Madmen',
#   'The Outsider',
#   'The man in the high castle',
#   'The Wire',
#   'Only Murders in the building',
#   'Sherlock'],
#  ['Demon Slayer',
#   'Mr. Robot',
#   'White Collar',
#   'Prison Break',
#   '12 Monkeys',
#   'Vikings',
#   'Sherlock',
#   'Space Force',
#   'The Mentalist',
#   'Shadow and Bone'],
#  ['The Blacklist',
#   'Demon Slayer',
#   'Sex Education',
#   'Preacher',
#   'Deception',
#   'The Outsider',
#   'Stranger Things',
#   'Lucifer'],
#  ['Daredevil',
#   'The Stranger',
#   'Sex Education',
#   'Breaking Bad',
#   'Deception',
#   'Two and a half men',
#   'Locke & Key',
#   '12 Monkeys',
#   'Vikings',
#   'Altered Carbon',
#   'Lost in Space',
#   'Big Little Lies'],
#  ['Rick And Morty',
#   'Mr. Robot',
#   'Sex Education',
#   'Jack Ryan',
#   'Supergirl',
#   'Dr. House',
#   'Two and a half men'],
#  ['The Blacklist', 'Archer', 'The Night Manager', 'The Office', 'Lucifer'],
#  ['The Boys',
#   'Rick And Morty',
#   'Berlin Station',
#   'Deception',
#   'Stranger Things',
#   'Outer Banks',
#   'The IT Crowd'],
#  ['Jack Ryan', 'Emily in Paris', 'The Walking Dead', 'Peaky Blinders'],
#  ['Shooter'],
#  ['Hanna', 'Two and a half men', 'The Tick', 'Lucifer'],
#  ['Constantine',
#   'Atypical',
#   'Kingdom',
#   'The Walking Dead',
#   'Outer Banks',
#   'Banshee',
#   'Haven',
#   'Elite'],
#  ['Hanna', 'Mr. Robot', 'How I met your mother'],
#  ['Daredevil', 'Outer Banks', 'Dark'],
#  ['The Blacklist',
#   'Demon Slayer',
#   'The Boys',
#   'Mr. Robot',
#   'Person of Interest',
#   'Atypical',
#   'Punisher',
#   'Ragnarok',
#   'Peaky Blinders',
#   'Lucifer'],
#  ['Cobra Kai',
#   'Ozark',
#   'Atypical',
#   'Madmen',
#   'Two and a half men',
#   'Outer Banks',
#   'Shadow and Bone',
#   'How I met your mother'],
#  ['Daredevil', 'Sex Education', 'Absentia'],
#  ['Sex Education', 'Preacher', 'Archer'],
#  ['Lost', 'Deception'],
#  ['Emily in Paris', 'Stranger Things', 'Mare of Easttown'],
#  ['Hanna',
#   'The Wire',
#   'The Blacklist',
#   'Succession',
#   'Only Murders in the building',
#   'Punisher',
#   'Homeland',
#   'The IT Crowd'],
#  ['One Piece', 'Ozark', 'Jack Ryan'],
#  ['Friends'],
#  ['Constantine', 'Alice in Borderland', 'The Flash', 'The Wire', 'Kingdom'],
#  ['Sex Education', 'Two and a half men'],
#  ['Cobra Kai',
#   'The Blacklist',
#   'Sex Education',
#   'Atypical',
#   'Two and a half men',
#   'The Walking Dead',
#   'Lupin',
#   'Dark',
#   'Chernobyl'],
#  ['Arrow', 'Ozark', 'The Flash', 'The Walking Dead', 'The Alienist'],
#  ['Two and a half men', 'How I met your mother'],
#  ['Absentia'],
#  ['Supernatural'],
#  ['Absentia'],
#  ['The Mentalist', 'Peaky Blinders', 'Lucifer'],
#  ['The Wire', 'One Piece', 'The Blacklist', 'Mr. Robot', 'Ozark'],
#  ['Queen of the South',
#   'Cobra Kai',
#   'Locke & Key',
#   'Nine Perfect Strangers',
#   'Outer Banks',
#   'The Mentalist',
#   'The Tick',
#   'Lucifer'],
#  ['Demon Slayer',
#   'Atypical',
#   'Alice in Borderland',
#   'Deception',
#   'Dr. House',
#   'Lost in Space',
#   'Inside Job',
#   'Goliath',
#   'Chernobyl'],
#  ['The Wire', 'The Flash', 'Dark'],
#  ['Arrow',
#   'Sex Education',
#   'Constantine',
#   'Breaking Bad',
#   'Stranger Things',
#   'Outer Banks',
#   'The Mentalist',
#   'Shadow and Bone'],
#  ['Outer Banks', 'Mare of Easttown'],
#  ['Dark', 'The 100'],
#  ['The Wire', 'Two and a half men', 'Outer Banks'],
#  ['Rick And Morty',
#   'Sex Education',
#   'Atypical',
#   'Vikings',
#   'The IT Crowd',
#   'Startup'],
#  ['Outer Banks', 'Absentia'],
#  ['Queen of the South',
#   'Cobra Kai',
#   'Sex Education',
#   'Dr. House',
#   'Two and a half men',
#   'The Walking Dead',
#   'Sense 8',
#   'Homeland',
#   'The Mentalist'],
#  ['Rick And Morty', 'Family Guy'],
#  ['The Wire',
#   'Cobra Kai',
#   'The Blacklist',
#   'Mr. Robot',
#   'Ozark',
#   'Sex Education',
#   'Berlin Station',
#   'Atypical',
#   'Alice in Borderland',
#   'Deception',
#   'Locke & Key',
#   'Fringe',
#   'Punisher',
#   'Stranger Things',
#   'Homeland',
#   'Goliath',
#   'Gotham'],
#  ['Inhumans',
#   'Mr. Robot',
#   'Ozark',
#   'Breaking Bad',
#   'The Walking Dead',
#   'Vikings',
#   'Perception'],
#  ['Shadow and Bone', 'The Night Manager'],
#  ['Gotham'],
#  ['Jack Ryan', 'Atypical', 'Dr. House', 'The Wire', 'Dexter', 'Banshee'],
#  ['Stranger Things', 'The Night Manager'],
#  ['The Stranger',
#   'Mr. Robot',
#   'Ozark',
#   'Sex Education',
#   'Berlin Station',
#   'Atypical',
#   'Dr Stone',
#   'Dr. House',
#   'The Walking Dead',
#   'Locke & Key',
#   'Black Clover',
#   'Mare of Easttown',
#   'Perception',
#   'Startup'],
#  ['Dark'],
#  ['Doctor Who', 'Outer Banks', 'Designated Survivor'],
#  ['The Big Bang Theory', 'Westworld'],
#  ['Daredevil',
#   'Lost',
#   'The Blacklist',
#   'Mr. Robot',
#   'Sex Education',
#   'White Collar',
#   'Dr. House',
#   'Two and a half men',
#   'Lupin',
#   '12 Monkeys',
#   'Lost in Space',
#   'Outer Banks',
#   'The Mentalist'],
#  ['The Blacklist',
#   'Prison Break',
#   'Nine Perfect Strangers',
#   'Stranger Things',
#   'The Mentalist',
#   'Designated Survivor'],
#  ['Demon Slayer',
#   'Rick And Morty',
#   'Mr. Robot',
#   'Ozark',
#   'Sex Education',
#   'Family Guy'],
#  ['Archer'],
#  ['The Night Manager'],
#  ['Daredevil', 'Two and a half men'],
#  ['Daredevil', 'Rick And Morty', 'Alice in Borderland', 'Preacher'],
#  ['Cobra Kai'],
#  ['Atypical', 'Emily in Paris', 'Stranger Things', 'Brooklyn Nine Nine'],
#  ['Dark', 'Lucifer'],
#  ['The Stranger',
#   'Ozark',
#   'Sex Education',
#   'Dr. House',
#   'Only Murders in the building',
#   '12 Monkeys',
#   'Vikings',
#   'Archer',
#   'Dark',
#   'Brooklyn Nine Nine',
#   'The Night Manager'],
#  ['Mare of Easttown',
#   'The Mentalist',
#   'Absentia',
#   'The Alienist',
#   'Shadow and Bone',
#   'Lucifer'],
#  ['Outer Banks', 'Absentia'],
#  ['Demon Slayer', 'Sex Education', 'Family Guy'],
#  ['One Piece',
#   'Demon Slayer',
#   'Ozark',
#   'Travellers',
#   'The Wire',
#   'The Walking Dead',
#   'Outer Banks',
#   'The Mentalist'],
#  ['Jack Ryan',
#   'The Wire',
#   'The Walking Dead',
#   'Outer Banks',
#   'How to get away with murder',
#   'Suits',
#   'Spartacus',
#   'The Alienist',
#   'Shadow and Bone',
#   'Designated Survivor'],
#  ['Sex Education'],
#  ['Demon Slayer',
#   'Ozark',
#   'Berlin Station',
#   'Atypical',
#   'Family Guy',
#   'Kingdom',
#   'The Walking Dead',
#   'The Mentalist',
#   'Perception'],
#  ['Cobra Kai', 'Archer', 'Absentia', 'The Alienist', 'Lucifer'],
#  ['Queen of the South', 'The Boys', 'Perception'],
#  ['Queen of the South',
#   'The Blacklist',
#   'Ozark',
#   'Sex Education',
#   'Preacher',
#   'Two and a half men',
#   'Sopranos',
#   'Stranger Things',
#   'Locke & Key',
#   'The Tick'],
#  ['Kingdom', 'Stranger Things', 'Outer Banks', 'Absentia'],
#  ['Gotham'],
#  ['Family Guy', 'White Collar', 'Dr. House'],
#  ['The Blacklist'],
#  ['Person of Interest', 'Sex Education'],
#  ['The Wire',
#   'One Piece',
#   'The Blacklist',
#   'Rick And Morty',
#   'Punisher',
#   'Black Clover',
#   'Ragnarok'],
#  ['How I met your mother'],
#  ['Cobra Kai',
#   'Rick And Morty',
#   'Ozark',
#   'Sex Education',
#   'Doctor Who',
#   'How I met your mother'],
#  ['Succession',
#   'Ozark',
#   "Grey's Anatomy",
#   'The Flash',
#   "The Queen's Gambit",
#   'Designated Survivor'],
#  ['House of Cards', 'Suits'],
#  ['Cobra Kai',
#   'Rick And Morty',
#   'Ozark',
#   'Sex Education',
#   'Constantine',
#   'Family Guy',
#   'Preacher',
#   'Stranger Things'],
#  ['Altered Carbon', '24', 'Stranger Things'],
#  ['Lost',
#   'Preacher',
#   'Mindhunter',
#   'Archer',
#   'Absentia',
#   'The IT Crowd',
#   'Lucifer'],
#  ['Queen of the South',
#   'Cobra Kai',
#   'The Boys',
#   'Mr. Robot',
#   'Two and a half men',
#   'Nine Perfect Strangers',
#   'Shadow and Bone'],
#  ['Mare of Easttown'],
#  ['Hanna', 'Cobra Kai', 'Shooter', 'Archer'],
#  ['Sex Education', 'Two and a half men', 'Sense 8', 'Mirzapur', 'Dark'],
#  ['Hanna',
#   'Daredevil',
#   'The Blacklist',
#   'Mr. Robot',
#   'Sex Education',
#   'Alice in Borderland',
#   'Deception',
#   'Sopranos',
#   'Lost in Space',
#   'How to get away with murder'],
#  ['Cobra Kai', 'Mr. Robot', '12 Monkeys', 'The Witcher', 'Lucifer'],
#  ['Sex Education', 'Stranger Things', 'The Mentalist'],
#  ['The Wire',
#   'The Stranger',
#   'Rick And Morty',
#   'Atypical',
#   'Family Guy',
#   'Preacher',
#   'True Detective',
#   'Kingdom',
#   'Banshee'],
#  ['Arrow',
#   'The Stranger',
#   'Cobra Kai',
#   'Ozark',
#   'Sex Education',
#   'Atypical',
#   'Family Guy',
#   'Dark',
#   'Shadow and Bone',
#   'The Good Doctor',
#   'Peaky Blinders'],
#  ['Hanna',
#   'Daredevil',
#   'Mr. Robot',
#   'Two and a half men',
#   'Lost in Space',
#   'How I met your mother'],
#  ['Sex Education', 'The Outsider', 'The Walking Dead', 'Archer', 'Lucifer'],
#  ['Breaking Bad', 'Sons of Anarchy', 'Ragnarok'],
#  ['Sex Education'],
#  ['Sex Education', 'Sacred Games'],
#  ['The Blacklist', 'Stranger Things'],
#  ['Family Guy'],
#  ['Cobra Kai', 'Sex Education', 'The Walking Dead'],
#  ['The Witcher', 'How I met your mother', 'Lucifer'],
#  ['Outer Banks'],
#  ['The Stranger',
#   'Ozark',
#   'Sex Education',
#   'Atypical',
#   'Deception',
#   'Archer',
#   'Dark',
#   'Locke & Key'],
#  ['Sex Education', 'Doctor Who', 'Stranger Things'],
#  ['The Stranger',
#   'The Blacklist',
#   'Mr. Robot',
#   'Sex Education',
#   'The Wire',
#   'Brooklyn Nine Nine',
#   'Lucifer'],
#  ['The Wire', 'The Stranger', 'Ozark', 'Sex Education'],
#  ['Daredevil',
#   'The Blacklist',
#   'Mr. Robot',
#   'Sex Education',
#   'Atypical',
#   'The man in the high castle',
#   'The Walking Dead'],
#  ['Hanna',
#   'Ozark',
#   'Atypical',
#   'White Collar',
#   "Grey's Anatomy",
#   'Dr. House',
#   'Two and a half men',
#   'Hunters'],
#  ['Emily in Paris',
#   'The Walking Dead',
#   'Outer Banks',
#   'Mare of Easttown',
#   'Outlander'],
#  ['Cobra Kai', 'Sex Education', 'Lupin'],
#  ['Mr. Robot',
#   'Ozark',
#   'Dr. House',
#   'Vikings',
#   'Dexter',
#   'Stranger Things',
#   'Outer Banks',
#   'Dark',
#   'Locke & Key',
#   'Spartacus',
#   'Designated Survivor'],
#  ['Chernobyl', 'The Tick'],
#  ['Daredevil',
#   'Arrow',
#   'One Piece',
#   'Lost',
#   'Cobra Kai',
#   'Sex Education',
#   'Berlin Station',
#   'Atypical',
#   'Family Guy',
#   'Alice in Borderland',
#   'The Flash',
#   'Preacher',
#   'Doctor Who',
#   'Kingdom'],
#  ['Daredevil', 'Atypical', 'The Mentalist', 'Lucifer'],
#  ['Lost',
#   'Cobra Kai',
#   'Ozark',
#   'Sex Education',
#   'Berlin Station',
#   'Two and a half men',
#   'Punisher',
#   'American Gods',
#   'Designated Survivor',
#   'Westworld'],
#  ['The Wire',
#   'Ozark',
#   'Sex Education',
#   'The Flash',
#   'The Mentalist',
#   'Banshee'],
#  ['Constantine', 'Upload'],
#  ['Absentia'],
#  ['Sex Education', 'Stranger Things', 'Outer Banks', 'Absentia'],
#  ['The Outsider', 'How I met your mother'],
#  ['Person of Interest',
#   'Sex Education',
#   'Jack Ryan',
#   'The Witcher',
#   'Outer Banks'],
#  ['Arrow',
#   'Ozark',
#   'Family Guy',
#   'The Flash',
#   'Two and a half men',
#   'Outer Banks',
#   'Mare of Easttown',
#   'Shadow and Bone',
#   'The Night Manager'],
#  ['Demon Slayer'],
#  ['Absentia'],
#  ['Dark'],
#  ['Demon Slayer',
#   'Emily in Paris',
#   'Doctor Who',
#   'Banshee',
#   'Shadow and Bone',
#   'Chernobyl'],
#  ['Hanna', 'Atypical'],
#  ['Atypical', 'White Collar', 'Upload', 'Stranger Things', 'Dark'],
#  ['Cobra Kai',
#   'The Blacklist',
#   'Sex Education',
#   'Travellers',
#   'Emily in Paris',
#   'Outer Banks',
#   'Lucifer'],
#  ['Arrow',
#   'The Blacklist',
#   'Demon Slayer',
#   'Ozark',
#   'White Collar',
#   'Alice in Borderland',
#   'Dr. House',
#   'The Wire',
#   'The Mentalist'],
#  ['The Blacklist', 'Travellers', 'Punisher'],
#  ['Stranger Things', 'Mare of Easttown'],
#  ['Daredevil',
#   'Arrow',
#   'The Stranger',
#   'Ozark',
#   'Sex Education',
#   'Berlin Station',
#   'Family Guy',
#   'Preacher'],
#  ['Daredevil', 'Outer Banks', 'Outlander'],
#  ['Only Murders in the building'],
#  ['Cobra Kai'],
#  ['The Wire',
#   'One Piece',
#   'Ozark',
#   'Sex Education',
#   'Alice in Borderland',
#   'The Walking Dead',
#   'Vikings',
#   'Fringe',
#   'The White Lotus'],
#  ['Stranger Things'],
#  ['Daredevil',
#   'The Blacklist',
#   'Preacher',
#   'The Walking Dead',
#   'Stranger Things'],
#  ['Outer Banks'],
#  ['Dark'],
#  ['Rick And Morty',
#   'Berlin Station',
#   'Dr. House',
#   'Outer Banks',
#   'Locke & Key'],
#  ['Sex Education', 'The Outsider', 'Lucifer'],
#  ['Absentia'],
#  ['Cobra Kai', 'The Blacklist', 'Succession', 'Ozark', 'Lucifer'],
#  ['The Wire', 'Stranger Things', 'Outer Banks', 'Dark'],
#  ['Queen of the South',
#   'Lost',
#   'Rick And Morty',
#   'Mr. Robot',
#   'Succession',
#   'Ozark',
#   'Constantine',
#   'Atypical',
#   'Doctor Who',
#   'Two and a half men',
#   'Vikings',
#   'The Witcher',
#   'Outer Banks',
#   'The Mentalist',
#   'How to get away with murder',
#   'Suits',
#   'Haven'],
#  ['Demon Slayer', 'Ozark', 'The Mentalist'],
#  ['The Walking Dead'],
#  ['Stranger Things', 'Chernobyl'],
#  ['Arrow',
#   'The Blacklist',
#   'Emily in Paris',
#   'The Wire',
#   'The Walking Dead',
#   'Spartacus',
#   'Designated Survivor',
#   'Brooklyn Nine Nine'],
#  ['Ozark',
#   'Sex Education',
#   'Preacher',
#   'Doctor Who',
#   'Two and a half men',
#   'Kingdom',
#   'Stranger Things',
#   'How I met your mother'],
#  ['White Collar', 'Two and a half men'],
#  ['Ozark',
#   'Atypical',
#   "Grey's Anatomy",
#   'Dr. House',
#   'Kingdom',
#   'Sense 8',
#   'The Witcher',
#   'Archer',
#   'Stranger Things',
#   'Absentia',
#   'Designated Survivor',
#   'Brooklyn Nine Nine',
#   'Perception',
#   'The Good Doctor',
#   'Chernobyl',
#   'Lucifer'],
#  ['Sex Education', 'Atypical', 'Breaking Bad', 'Lost in Space', 'Outer Banks'],
#  ['Outer Banks', 'Shadow and Bone', 'The Night Manager'],
#  ['Rick And Morty'],
#  ['Absentia'],
#  ['The Stranger',
#   'Into the night',
#   'Sex Education',
#   'Berlin Station',
#   'Jack Ryan',
#   'Preacher'],
#  ["Grey's Anatomy",
#   'Two and a half men',
#   'Kingdom',
#   'Homeland',
#   'How I met your mother',
#   'Lucifer'],
#  ['Absentia', 'How I met your mother'],
#  ['Outer Banks', 'Dark'],
#  ['Outer Banks', 'Designated Survivor'],
#  ['Absentia'],
#  ['Lost', 'Sex Education', 'Mare of Easttown', 'Locke & Key'],
#  ['The Wheel of Time', 'Westworld'],
#  ['The Nevers', 'Space Force', 'Outer Banks'],
#  ['Modern Family', 'Riverdale'],
#  ['Dark', 'Rome'],
#  ['Lupin', 'Stranger Things'],
#  ['One Piece',
#   'Family Guy',
#   'Two and a half men',
#   'Only Murders in the building',
#   'Outer Banks',
#   'Banshee',
#   'Shadow and Bone',
#   'The Night Manager'],
#  ['Rick And Morty', 'Atypical'],
#  ['Cobra Kai',
#   'Upload',
#   'Dr. House',
#   'Two and a half men',
#   'The Walking Dead'],
#  ['Hanna',
#   'Daredevil',
#   'White Collar',
#   'Doctor Who',
#   'Upload',
#   'Dr. House',
#   'Two and a half men',
#   'The Walking Dead',
#   'Sopranos',
#   'Archer'],
#  ['Daredevil', 'Two and a half men'],
#  ['Cobra Kai',
#   'Ozark',
#   'Berlin Station',
#   'Outer Banks',
#   'Dark',
#   'Absentia',
#   'Spartacus',
#   'Shadow and Bone',
#   'Ragnarok'],
#  ['One Piece', 'White Collar', 'Stranger Things', 'Outer Banks', 'Absentia'],
#  ['One Piece',
#   'The Blacklist',
#   'Modern Family',
#   'Two and a half men',
#   'How I met your mother'],
#  ['The Stranger',
#   'Cobra Kai',
#   'Succession',
#   'Ozark',
#   'Sex Education',
#   'Supergirl',
#   'Sense 8',
#   'Game of thrones',
#   'Vikings',
#   'Lost in Space'],
#  ['Deception', 'House of Cards', 'Stranger Things', 'Outer Banks'],
#  ['Cobra Kai',
#   'Mr. Robot',
#   'Ozark',
#   'Sex Education',
#   'Berlin Station',
#   'Jack Ryan',
#   'Only Murders in the building',
#   'Shooter',
#   'Big Little Lies',
#   'How I met your mother'],
#  ['The Walking Dead', 'Outer Banks'],
#  ['The Blacklist',
#   'Jack Ryan',
#   'Two and a half men',
#   'Death Note',
#   'How I met your mother'],
#  ['One Piece',
#   'Lost',
#   'Cobra Kai',
#   'Rick And Morty',
#   'Succession',
#   'Family Guy',
#   'Locke & Key',
#   'Archer',
#   'Shadow and Bone'],
#  ['Sex Education', 'Archer', 'Goliath', 'Lucifer'],
#  ['Chernobyl'],
#  ['Daredevil',
#   'Arrow',
#   'Cobra Kai',
#   'Ozark',
#   'Berlin Station',
#   'The Flash',
#   'Invincible',
#   'Dr. House',
#   'Two and a half men',
#   'Kingdom',
#   '12 Monkeys',
#   'Outer Banks',
#   'The Night Manager'],
#  ['Jack Ryan',
#   'Family Guy',
#   'Sherlock',
#   'The Night Manager',
#   'The Expanse',
#   'Lucifer'],
#  ['The Blacklist', 'Ozark'],
#  ['Two and a half men', 'Stranger Things', 'Designated Survivor'],
#  ['Dark'],
#  ['Outer Banks'],
#  ['Two and a half men'],
#  ['Daredevil',
#   'The Stranger',
#   'Succession',
#   'Ozark',
#   'Better Call Saul',
#   'Berlin Station',
#   'Atypical',
#   'Emily in Paris',
#   'The Flash',
#   'Deception',
#   'Dr. House',
#   'The Wire',
#   'Stranger Things',
#   'Outer Banks',
#   'The Mentalist',
#   'Dark',
#   'Absentia',
#   'Friends',
#   'Spartacus',
#   'Shadow and Bone',
#   'The Night Manager',
#   'Bojack Horseman',
#   'The Wheel of Time'],
#  ['The Stranger',
#   'One Piece',
#   'The Blacklist',
#   'Family Guy',
#   'Only Murders in the building',
#   'Archer',
#   'Outer Banks',
#   'Lucifer'],
#  ['The Wire',
#   'Cobra Kai',
#   'Atypical',
#   'Prison Break',
#   'Deception',
#   'The Vampire Diaries',
#   '24',
#   'Black Clover'],
#  ['Hanna',
#   'Daredevil',
#   'Cobra Kai',
#   'Mr. Robot',
#   'Ozark',
#   'Atypical',
#   "Grey's Anatomy",
#   'Madmen',
#   'Two and a half men',
#   'Stranger Things'],
#  ['Demon Slayer', 'Outer Banks', 'Friends'],
#  ['The 100'],
#  ['Demon Slayer'],
#  ['Sex Education', 'Narcos'],
#  ['Cobra Kai', 'Person of Interest', 'Ozark', 'Jack Ryan'],
#  ['One Piece',
#   'Mr. Robot',
#   'Ozark',
#   'Sex Education',
#   'Dr. House',
#   'The Walking Dead'],
#  ['Rick And Morty',
#   'Atypical',
#   'Mare of Easttown',
#   'Absentia',
#   'The 100',
#   'Haven'],
#  ['The Outsider', 'Outer Banks', 'Mare of Easttown', 'The Newsroom'],
#  ['Ozark', 'Sex Education', 'Two and a half men'],
#  ['Sex Education',
#   'Jack Ryan',
#   'Atypical',
#   'Family Guy',
#   'Shooter',
#   'Outer Banks',
#   'Lucifer'],
#  ['Mr. Robot'],
#  ['Ozark',
#   'Sex Education',
#   'Atypical',
#   'The Outsider',
#   'Game of thrones',
#   '12 Monkeys',
#   'Punisher',
#   'Sherlock'],
#  ['One Piece',
#   'The Blacklist',
#   'Mr. Robot',
#   'Family Guy',
#   'Deception',
#   'Sense 8'],
#  ['Queen of the South',
#   'Sex Education',
#   'Berlin Station',
#   'Atypical',
#   'Deception',
#   'Dr. House',
#   'Two and a half men',
#   'Archer',
#   'Dark',
#   'You'],
#  ['One Piece', 'Emily in Paris'],
# ...
#  ['Emily in Paris'],
#  ['Daredevil',
#   'Constantine',
#   'Alice in Borderland',
#   'Kingdom',
#   'Perception',
#   'The White Lotus',
#   'Peaky Blinders',
#   'Lucifer'],
#  ['One Piece', 'Deception', 'The Walking Dead', 'Mare of Easttown'],
#  ['Mr. Robot', 'Ozark', 'Atypical'],
#  ['Constantine', 'The Mentalist', 'Loki', 'Brooklyn Nine Nine'],
#  ['Sex Education', 'Kingdom', 'The Walking Dead'],
#  ['Demon Slayer', 'The Alienist'],
#  ['Ozark',
#   'Sex Education',
#   'Berlin Station',
#   'Dr. House',
#   'Spartacus',
#   'The Night Manager',
#   'Ragnarok',
#   'Perception'],
#  ['Hanna',
#   'One Piece',
#   'Queen of the South',
#   'The Blacklist',
#   'Mr. Robot',
#   'Ozark',
#   'Berlin Station',
#   'Two and a half men',
#   'The Walking Dead',
#   'Archer',
#   'The Mentalist',
#   'Shadow and Bone',
#   'Big Little Lies',
#   'How I met your mother'],
#  ['Dark', 'Loki'],
#  ['Two and a half men', 'Lucifer'],
#  ['Outer Banks'],
#  ['Demon Slayer', 'Outer Banks', 'Haven', 'Designated Survivor'],
#  ['Outer Banks', 'Loki', 'The Expanse'],
#  ['One Piece'],
#  ['Sex Education', 'Deception'],
#  ['Riverdale'],
#  ['Daredevil',
#   'Queen of the South',
#   'Mr. Robot',
#   'Ozark',
#   'The Wire',
#   'The Walking Dead',
#   'Outer Banks',
#   'Lucifer'],
#  ['Only Murders in the building', 'The Mentalist'],
#  ['The Stranger'],
#  ['The Wire', 'Absentia'],
#  ['Kingdom', 'Orphan Black', 'The Umbrella Academy'],
#  ['Two and a half men', 'Kingdom'],
#  ['The Blacklist',
#   'Ozark',
#   'Two and a half men',
#   'The Wire',
#   'Dark',
#   'Peaky Blinders'],
#  ['Demon Slayer',
#   'Rick And Morty',
#   'Ozark',
#   'Sex Education',
#   'Atypical',
#   'Dr. House',
#   'Two and a half men',
#   'The Walking Dead',
#   '12 Monkeys'],
#  ['One Piece',
#   'The Blacklist',
#   'Demon Slayer',
#   'Sex Education',
#   'Family Guy',
#   'Perception',
#   'The Good Doctor',
#   'Chernobyl',
#   'Lucifer'],
#  ['Family Guy'],
#  ['One Piece', 'Sex Education', 'Constantine'],
#  ['Absentia', 'Spartacus', 'Shadow and Bone'],
#  ['Mr. Robot',
#   'Better Call Saul',
#   'Berlin Station',
#   'Family Guy',
#   'Two and a half men'],
#  ['Designated Survivor'],
#  ['Demon Slayer',
#   'Travellers',
#   'White Collar',
#   'The Outsider',
#   'Two and a half men',
#   'Westworld',
#   'How I met your mother'],
#  ['Two and a half men', 'The Mentalist'],
#  ['Travellers', 'Brooklyn Nine Nine', 'Chernobyl'],
#  ['Succession', 'Two and a half men'],
#  ['The Night Manager'],
#  ['Hanna', 'Two and a half men', 'Absentia'],
#  ['Dark'],
#  ['The Blacklist', 'Constantine', 'Atypical', 'Homeland', 'Big Little Lies'],
#  ['Perception', 'Grimm', 'Big Little Lies'],
#  ['Demon Slayer'],
#  ['Ozark',
#   'Better Call Saul',
#   'Constantine',
#   'Deception',
#   'Dr. House',
#   'Game of thrones',
#   'The Innocent',
#   'Vikings'],
#  ['Two and a half men', 'Rome'],
#  ['The Stranger',
#   'One Piece',
#   'The Boys',
#   'Ozark',
#   'Dr. House',
#   'Two and a half men',
#   'The Walking Dead',
#   'Outer Banks',
#   'Brooklyn Nine Nine'],
#  ['Preacher', 'Designated Survivor'],
#  ['Stranger Things', 'The Newsroom', 'Brooklyn Nine Nine'],
#  ['Loki'],
#  ['Ozark', 'Two and a half men'],
#  ['Hanna',
#   'Lost',
#   'Sex Education',
#   'Archer',
#   'Stranger Things',
#   'Dark',
#   'Spartacus',
#   'Shadow and Bone'],
#  ['The Blacklist', 'Ozark', 'Archer'],
#  ['The Wire',
#   'Queen of the South',
#   'Mr. Robot',
#   'Ozark',
#   'Berlin Station',
#   'Atypical',
#   'Deception',
#   'Doctor Who',
#   'Archer',
#   'Banshee',
#   'Lucifer'],
#  ['Hanna', 'Sex Education'],
#  ['Rome'],
#  ['Sex Education',
#   'House of Cards',
#   'Sopranos',
#   'Sons of Anarchy',
#   'Nine Perfect Strangers',
#   'Outer Banks',
#   'How I met your mother'],
#  ['Atypical'],
#  ['Cobra Kai',
#   'Mr. Robot',
#   'Better Call Saul',
#   'Sex Education',
#   'Atypical',
#   'The Witcher',
#   'Stranger Things',
#   'Shadow and Bone',
#   'Chernobyl'],
#  ['Into the night',
#   'The Blacklist',
#   'Mr. Robot',
#   'Ozark',
#   'Jack Ryan',
#   'Family Guy',
#   'The Newsroom'],
#  ['Hanna',
#   'One Piece',
#   'Queen of the South',
#   'The Blacklist',
#   'Ozark',
#   'Sex Education',
#   'Atypical',
#   'Two and a half men',
#   'Lupin',
#   'Lost in Space',
#   'Outer Banks',
#   'How I met your mother'],
#  ['The Blacklist',
#   'Mr. Robot',
#   'Deception',
#   'The Outsider',
#   'Stranger Things',
#   'The IT Crowd'],
#  ['Only Murders in the building'],
#  ['Riverdale'],
#  ['The Blacklist',
#   'Demon Slayer',
#   'Sex Education',
#   'Two and a half men',
#   'The Walking Dead',
#   'The Mentalist',
#   'How to get away with murder',
#   'Perception',
#   'Banshee'],
#  ['Sex Education', 'Kingdom'],
#  ['Cobra Kai', 'Berlin Station', 'White Collar', '12 Monkeys', 'Dark'],
#  ['Daredevil',
#   'Arrow',
#   'Queen of the South',
#   'Cobra Kai',
#   'Rick And Morty',
#   'Atypical',
#   'Madmen',
#   'Two and a half men',
#   'The Witcher',
#   'Shadow and Bone',
#   'Brooklyn Nine Nine'],
#  ['Emily in Paris', 'Doctor Who', 'Brooklyn Nine Nine', 'The Night Manager'],
#  ['Lost',
#   'Succession',
#   'Sex Education',
#   'Two and a half men',
#   'House of Cards'],
#  ['The Blacklist',
#   'Sex Education',
#   'The Flash',
#   'Two and a half men',
#   'The Witcher',
#   'Stranger Things',
#   'Hunters'],
#  ['Designated Survivor'],
#  ['Demon Slayer',
#   'Mr. Robot',
#   'Sex Education',
#   'Atypical',
#   'The Wire',
#   'Outer Banks',
#   'Shadow and Bone',
#   'Big Little Lies'],
#  ['The Mentalist', 'How to get away with murder'],
#  ['Atypical', 'The Mentalist', 'How I met your mother'],
#  ['Sex Education'],
#  ['The Stranger'],
#  ['Ozark', 'Travellers', 'White Collar', 'Kingdom', 'Stranger Things'],
#  ['Mr. Robot',
#   'Person of Interest',
#   'Atypical',
#   'Family Guy',
#   'White Collar',
#   'Deception',
#   'Banshee'],
#  ['The Wire',
#   'The Stranger',
#   'One Piece',
#   'Mr. Robot',
#   'Sex Education',
#   'Two and a half men',
#   'Perception'],
#  ['Hanna',
#   'White Collar',
#   'The Flash',
#   'Madmen',
#   'Kingdom',
#   'The Walking Dead',
#   'Stranger Things',
#   'Ragnarok',
#   'Lucifer'],
#  ['Absentia', 'How I met your mother'],
#  ['Arrow', 'Berlin Station', 'Prison Break'],
#  ['Hanna',
#   'Queen of the South',
#   'The Blacklist',
#   'Mr. Robot',
#   'Better Call Saul',
#   'Sex Education',
#   'Deception'],
#  ['Sex Education', "Grey's Anatomy", 'Two and a half men', 'Kingdom'],
#  ['Sex Education', 'Archer'],
#  ['Mr. Robot', 'Atypical', 'Emily in Paris'],
#  ['Daredevil', 'Mr. Robot', 'Dr. House', 'Hunters'],
#  ['Ozark', 'Two and a half men', 'Black Clover'],
#  ['Sex Education', 'The Outsider', 'Sherlock'],
#  ['Dark'],
#  ['Cobra Kai',
#   'Sex Education',
#   'Dr. House',
#   'Altered Carbon',
#   'Nine Perfect Strangers',
#   'Mare of Easttown',
#   'Perception'],
#  ['Spartacus', 'Designated Survivor'],
#  ['The Blacklist',
#   'Ozark',
#   'Sex Education',
#   'Jack Ryan',
#   'Upload',
#   'Two and a half men',
#   '12 Monkeys',
#   'The Nevers'],
#  ['Designated Survivor'],
#  ['Queen of the South',
#   'Cobra Kai',
#   'The Blacklist',
#   'Demon Slayer',
#   'Constantine',
#   'Preacher',
#   'Two and a half men',
#   'Shadow and Bone'],
#  ['Ozark', 'Sex Education', 'Jack Ryan'],
#  ['Mr. Robot'],
#  ['Outer Banks'],
#  ['Dark'],
#  ['Sex Education', 'Deception', 'Stranger Things'],
#  ['Absentia', 'How I met your mother'],
#  ['One Piece'],
#  ['Hanna',
#   'Sex Education',
#   'Breaking Bad',
#   'The Outsider',
#   'Black Clover',
#   'Big Little Lies',
#   'The IT Crowd'],
#  ['Dark'],
#  ['Cobra Kai', 'The Blacklist', 'Only Murders in the building'],
#  ['Mr. Robot',
#   'Succession',
#   'Ozark',
#   'Sex Education',
#   'Jack Ryan',
#   'Atypical',
#   'Supergirl',
#   'Spartacus'],
#  ['Lucifer'],
#  ['Perception'],
#  ['Demon Slayer',
#   'Sex Education',
#   'Two and a half men',
#   'Vikings',
#   'Punisher'],
#  ['Daredevil', 'Ozark', 'Two and a half men'],
#  ['Sex Education'],
#  ['Cobra Kai',
#   'The Blacklist',
#   'Ozark',
#   'Sex Education',
#   'Jack Ryan',
#   'Two and a half men'],
#  ['Hanna',
#   'Sex Education',
#   'Atypical',
#   'Billions',
#   'Deception',
#   'Two and a half men',
#   'Perception'],
#  ['Sex Education', 'Travellers', 'Atypical'],
#  ['Hanna',
#   'The Wire',
#   'Lost',
#   'Rick And Morty',
#   'Sex Education',
#   'Berlin Station',
#   'House of Cards',
#   'Watchmen',
#   'Archer',
#   'The Mentalist',
#   'Chernobyl'],
#  ['Daredevil',
#   'The Blacklist',
#   'Ozark',
#   'Berlin Station',
#   'Alice in Borderland',
#   'Dr. House',
#   'Two and a half men',
#   'Kingdom',
#   'Chernobyl'],
#  ['One Piece', 'Breaking Bad', 'Dark'],
#  ['Arrow', 'Sex Education', 'The Wire', 'Dark'],
#  ['Sex Education', 'Berlin Station'],
#  ['Arrow',
#   'The Blacklist',
#   'Berlin Station',
#   'Preacher',
#   'Dr. House',
#   'The Wire',
#   'The Walking Dead',
#   'Homeland',
#   'The Mentalist',
#   'Shadow and Bone',
#   'Lucifer'],
#  ['Mr. Robot', 'Berlin Station', '12 Monkeys'],
#  ['Outer Banks'],
#  ['Absentia'],
#  ['The Stranger',
#   'Sex Education',
#   'Deception',
#   'Kingdom',
#   'Vikings',
#   'Nine Perfect Strangers'],
#  ['Emily in Paris', 'Banshee'],
#  ['Lost',
#   'Cobra Kai',
#   'Berlin Station',
#   'Deception',
#   'House of Cards',
#   'Mindhunter',
#   'Archer'],
#  ['Arrow',
#   'Succession',
#   'Ozark',
#   'Sex Education',
#   'Family Guy',
#   "Grey's Anatomy",
#   'Alice in Borderland',
#   'Kingdom',
#   'Shooter',
#   'Mindhunter',
#   'How to get away with murder',
#   'Designated Survivor',
#   'The Tick'],
#  ['Queen of the South'],
#  ['Rome', 'Locke & Key'],
#  ['Sex Education',
#   'Dr. House',
#   'Two and a half men',
#   'Kingdom',
#   'Designated Survivor',
#   'Lucifer'],
#  ['Sex Education',
#   'Family Guy',
#   'Two and a half men',
#   'Outer Banks',
#   'Spartacus',
#   'The Night Manager',
#   'The IT Crowd'],
#  ['One Piece'],
#  ['Hanna', 'Sex Education', 'Two and a half men', 'The IT Crowd', 'Lucifer'],
#  ['Atypical', 'Vikings', 'Lucifer'],
#  ['Daredevil',
#   'Queen of the South',
#   'The Blacklist',
#   'Ozark',
#   'Berlin Station',
#   'Atypical',
#   'White Collar',
#   'Prison Break',
#   'Alice in Borderland',
#   'The Innocent',
#   'The Big Bang Theory',
#   'Mindhunter',
#   'How I met your mother'],
#  ['Cobra Kai',
#   'Demon Slayer',
#   'Ozark',
#   'Sex Education',
#   'Deception',
#   'Stranger Things'],
#  ['Jack Ryan', 'Outer Banks'],
#  ['The Walking Dead', 'Outer Banks', 'Lucifer'],
#  ['Ozark'],
#  ['One Piece',
#   'Queen of the South',
#   'Cobra Kai',
#   'Demon Slayer',
#   'Mr. Robot',
#   'Succession',
#   'Ozark',
#   'Sex Education',
#   'Berlin Station',
#   'The Outsider',
#   'Stranger Things',
#   'Spartacus',
#   'How I met your mother',
#   'Lucifer'],
#  ['Sex Education',
#   'Doctor Who',
#   'The Walking Dead',
#   'The Mentalist',
#   'Spartacus'],
#  ['The Wire',
#   'Mr. Robot',
#   'Sex Education',
#   'Berlin Station',
#   'Breaking Bad',
#   'Dr. House',
#   'Stranger Things',
#   'Outer Banks',
#   'Big Little Lies'],
#  ['Archer'],
#  ['The Outsider'],
#  ['Archer'],
#  ['Demon Slayer', 'Berlin Station', 'Jack Ryan', 'Shadow and Bone'],
#  ['Better Call Saul',
#   'Sex Education',
#   'Emily in Paris',
#   'Two and a half men',
#   'Chernobyl'],
#  ['The Blacklist', 'Mr. Robot', 'Sex Education', 'Family Guy', 'Dr. House'],
#  ['Family Guy', 'Chernobyl'],
#  ['The Witcher', 'Shadow and Bone'],
#  ['The Stranger', 'Ozark', 'Two and a half men', 'Lucifer'],
#  ['Daredevil',
#   'Mr. Robot',
#   'Ozark',
#   'Sex Education',
#   'Berlin Station',
#   'Family Guy',
#   'Breaking Bad',
#   'Vikings',
#   'Punisher',
#   'The Nevers',
#   'Archer',
#   'Stranger Things',
#   'Outer Banks',
#   'The Mentalist',
#   'How to get away with murder',
#   'Banshee',
#   'The Night Manager',
#   'Chernobyl'],
#  ['Elementary', 'Rome', 'Lucifer'],
#  ['The Wire',
#   'Ozark',
#   'Sex Education',
#   'Emily in Paris',
#   'Two and a half men',
#   '12 Monkeys',
#   'Shadow and Bone',
#   'Chernobyl',
#   'How I met your mother'],
#  ['Hanna',
#   'The Wire',
#   'One Piece',
#   'Queen of the South',
#   'Rick And Morty',
#   'Ozark',
#   'Sex Education',
#   'Dr. House',
#   'Fringe',
#   'Archer',
#   'You'],
#  ['The Walking Dead', '12 Monkeys', 'Archer'],
#  ['The Blacklist',
#   'Sex Education',
#   'Travellers',
#   'Kingdom',
#   'Stranger Things'],
#  ['Travellers', 'Alice in Borderland'],
#  ['Outer Banks', 'The Mentalist'],
#  ['Outer Banks'],
#  ['The Walking Dead', 'Lupin', 'Vikings'],
#  ['Sex Education'],
#  ['Designated Survivor'],
#  ['Mr. Robot', 'Kingdom', 'Sopranos', 'The Witcher', 'Absentia'],
#  ['Outer Banks',
#   'Absentia',
#   'The Newsroom',
#   'Big Little Lies',
#   'Chernobyl',
#   'How I met your mother'],
#  ['Daredevil',
#   'The Wire',
#   'The Stranger',
#   'Lost',
#   'The Blacklist',
#   'Person of Interest',
#   'Ozark',
#   'The Outsider',
#   'The Wire',
#   'Outer Banks',
#   'Designated Survivor',
#   'Hunters',
#   'Schitts Creek'],
#  ['The Stranger', 'Cobra Kai', 'Two and a half men', 'Stranger Things'],
#  ['Daredevil', 'Two and a half men', 'Designated Survivor'],
#  ['Sex Education', 'Gotham'],
#  ['Dark'],
#  ['One Piece', 'How I met your mother'],
#  ['Demon Slayer',
#   'Emily in Paris',
#   'Deception',
#   'Doctor Who',
#   'Stranger Things',
#   'Outer Banks',
#   'How to get away with murder'],
#  ['Hanna',
#   'Arrow',
#   'Cobra Kai',
#   'The Blacklist',
#   'Demon Slayer',
#   'Mr. Robot',
#   'Person of Interest',
#   'Ozark',
#   'Sex Education',
#   'Atypical',
#   'Family Guy',
#   'Breaking Bad',
#   'Dr. House',
#   'The Wire',
#   'Archer',
#   'Dark'],
#  ['Absentia'],
#  ['Outer Banks'],
#  ['Cobra Kai', 'Lupin', 'How I met your mother'],
#  ['Ozark', 'Only Murders in the building'],
#  ['The Blacklist', '12 Monkeys'],
#  ['Daredevil',
#   "Grey's Anatomy",
#   'Two and a half men',
#   'Stranger Things',
#   'Designated Survivor'],
#  ['Outer Banks', 'The Mentalist'],
#  ['Daredevil',
#   'Two and a half men',
#   'Shadow and Bone',
#   'The Night Manager',
#   'Lucifer'],
#  ['Into the night',
#   'Ozark',
#   'Family Guy',
#   'Shooter',
#   'Dexter',
#   'Stranger Things',
#   'Locke & Key'],
#  ['Daredevil',
#   'The Wire',
#   'Into the night',
#   'Cobra Kai',
#   'The Blacklist',
#   'Demon Slayer',
#   'Mr. Robot',
#   'Succession',
#   'Person of Interest',
#   'Ozark',
#   'Sex Education',
#   'Jack Ryan',
#   'Atypical',
#   'Family Guy',
#   "Grey's Anatomy",
#   'Preacher',
#   'Deception',
#   'Kingdom',
#   'The Walking Dead',
#   'Lupin',
#   '12 Monkeys'],
#  ['The Outsider'],
#  ['White Collar'],
#  ['Absentia'],
#  ['Stranger Things', 'Outer Banks', 'Dark'],
#  ['Sex Education',
#   '12 Monkeys',
#   'Punisher',
#   'Stranger Things',
#   'Dark',
#   'Spartacus',
#   'Chernobyl'],
#  ['Dr. House'],
#  ['Queen of the South', 'Vikings', 'Absentia'],
#  ['Sex Education',
#   'Jack Ryan',
#   'Constantine',
#   'Mare of Easttown',
#   'Outlander',
#   'The IT Crowd',
#   'Startup',
#   'How I met your mother'],
#  ['The Walking Dead'],
#  ['Absentia'],
#  ['Sex Education', 'Designated Survivor'],
#  ['Stranger Things', 'How I met your mother'],
#  ['Big Little Lies'],
#  ['Absentia'],
#  ['Absentia'],
#  ['The Wire',
#   'Elementary',
#   'Ozark',
#   'Two and a half men',
#   'Kingdom',
#   'Outer Banks',
#   'Rome'],
#  ['Demon Slayer'],
#  ['Rick And Morty',
#   'Mr. Robot',
#   'Atypical',
#   'Family Guy',
#   'Inside Job',
#   'Rome',
#   'The White Lotus'],
#  ['Friends'],
#  ['Daredevil',
#   'Mr. Robot',
#   'Ozark',
#   'Berlin Station',
#   'Dr. House',
#   'Two and a half men'],
#  ['Two and a half men',
#   'Outer Banks',
#   'The Mentalist',
#   'Absentia',
#   'Rome',
#   'Banshee',
#   'Lucifer'],
#  ['Sex Education'],
#  ['Rick And Morty',
#   'Mr. Robot',
#   'The Flash',
#   'Madmen',
#   'Stranger Things',
#   'Outer Banks',
#   'Dark',
#   'Chernobyl'],
#  ['The Blacklist',
#   'Demon Slayer',
#   'Sex Education',
#   'Jack Ryan',
#   'Atypical',
#   'Kingdom',
#   'The Walking Dead',
#   'Sacred Games'],
#  ['Sex Education',
#   'Constantine',
#   'Deception',
#   'Two and a half men',
#   '12 Monkeys',
#   'Stranger Things',
#   'Locke & Key',
#   'How I met your mother'],
#  ['Hanna', 'Atypical', '12 Monkeys', 'Stranger Things'],
#  ['Hanna',
#   'Ozark',
#   'Atypical',
#   'Two and a half men',
#   'The Walking Dead',
#   '12 Monkeys',
#   'Vikings',
#   'Spartacus',
#   'Shadow and Bone',
#   'Outlander'],
#  ['One Piece', 'How I met your mother'],
#  ['Absentia'],
#  ['Demon Slayer',
#   'Stranger Things',
#   'Outer Banks',
#   'The Mentalist',
#   'Absentia',
#   'How I met your mother'],
#  ['Demon Slayer',
#   'Ozark',
#   'Atypical',
#   'Doctor Who',
#   'The Walking Dead',
#   'Spartacus',
#   'Brooklyn Nine Nine'],
#  ['Atypical', 'Brooklyn Nine Nine'],
#  ['Daredevil', 'Two and a half men', 'Riverdale'],
#  ['Two and a half men', '12 Monkeys'],
#  ['The Outsider'],
#  ['Succession',
#   'Berlin Station',
#   'Sense 8',
#   'Only Murders in the building',
#   'Chernobyl',
#   'How I met your mother'],
#  ['Outer Banks'],
#  ['Sex Education', 'Travellers', 'Preacher', 'Archer'],
#  ['Hanna', '12 Monkeys', 'The Wheel of Time'],
#  ['Outer Banks'],
#  ...]

# %% [markdown]
# #### **4) Aplicación del algoritmo**

# %% [markdown]
# **Configuración 1**
#
# Obtener reglas para aquellos artículos que se ven al menos 5 veces al día, entonces, 5 x 7 = 35 veces en una semana, entonces:
#
# i) El soporte mínimo se calcula de 35/7500 = 0.0045 (0.45%).
#
# ii) La confianza mínima para las reglas de 20%
#
# iii) La elevación de 3.

# %%
ReglasC1 = apriori(TransaccionesLista, 
                   min_support=0.0045, 
                   min_confidence=0.2, 
                   min_lift=3)

# %% [markdown]
# Se convierte las reglas encontradas por la clase apriori en una lista, puesto que es más fácil ver los resultados.

# %%
ResultadosC1 = list(ReglasC1)
print(len(ResultadosC1)) #Total de reglas encontradas
# Out:
# 66

# %%
ResultadosC1
# Out:
# [RelationRecord(items=frozenset({'Alice in Borderland', 'Daredevil'}), support=0.0071207430340557275, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Alice in Borderland'}), items_add=frozenset({'Daredevil'}), confidence=0.2875, lift=3.061401098901099)]),
#  RelationRecord(items=frozenset({'Arrow', 'The Wire'}), support=0.005779153766769866, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Arrow'}), items_add=frozenset({'The Wire'}), confidence=0.22134387351778656, lift=3.367067714893802)]),
#  RelationRecord(items=frozenset({'Dark', 'The 100'}), support=0.0046439628482972135, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The 100'}), items_add=frozenset({'Dark'}), confidence=0.41666666666666663, lift=4.6730324074074066)]),
#  RelationRecord(items=frozenset({'Punisher', 'Family Guy'}), support=0.0046439628482972135, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Punisher'}), items_add=frozenset({'Family Guy'}), confidence=0.26011560693641617, lift=3.6371143307559493)]),
#  RelationRecord(items=frozenset({'Rick And Morty', 'Family Guy'}), support=0.009184726522187823, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Rick And Morty'}), items_add=frozenset({'Family Guy'}), confidence=0.27639751552795033, lift=3.8647791132263185)]),
#  RelationRecord(items=frozenset({'Game of thrones', 'Vikings'}), support=0.004850361197110423, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Game of thrones'}), items_add=frozenset({'Vikings'}), confidence=0.2797619047619047, lift=8.29019222367846)]),
#  RelationRecord(items=frozenset({'Mr. Robot', 'Person of Interest'}), support=0.006914344685242518, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Person of Interest'}), items_add=frozenset({'Mr. Robot'}), confidence=0.4294871794871795, lift=3.926161103047896)]),
#  RelationRecord(items=frozenset({'Mr. Robot', 'Queen of the South'}), support=0.0173374613003096, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Queen of the South'}), items_add=frozenset({'Mr. Robot'}), confidence=0.3294117647058824, lift=3.011320754716982)]),
#  RelationRecord(items=frozenset({'Dr. House', '12 Monkeys', 'Sex Education'}), support=0.005159958720330237, ordered_statistics=[OrderedStatistic(items_base=frozenset({'12 Monkeys', 'Sex Education'}), items_add=frozenset({'Dr. House'}), confidence=0.2127659574468085, lift=3.3469190384083998)]),
#  RelationRecord(items=frozenset({'Atypical', 'Alice in Borderland', 'Sex Education'}), support=0.0046439628482972135, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Alice in Borderland', 'Sex Education'}), items_add=frozenset({'Atypical'}), confidence=0.42857142857142855, lift=3.0625790139064475)]),
#  RelationRecord(items=frozenset({'Berlin Station', 'Atypical', 'The Blacklist'}), support=0.0046439628482972135, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Berlin Station', 'Atypical'}), items_add=frozenset({'The Blacklist'}), confidence=0.31690140845070425, lift=3.0224159920150826), OrderedStatistic(items_base=frozenset({'Berlin Station', 'The Blacklist'}), items_add=frozenset({'Atypical'}), confidence=0.4591836734693877, lift=3.281334657756908)]),
#  RelationRecord(items=frozenset({'Atypical', 'The Blacklist', 'Demon Slayer'}), support=0.006501547987616099, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Atypical', 'Demon Slayer'}), items_add=frozenset({'The Blacklist'}), confidence=0.36, lift=3.4334645669291337)]),
#  RelationRecord(items=frozenset({'Atypical', 'Jack Ryan', 'Family Guy'}), support=0.0046439628482972135, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Atypical', 'Family Guy'}), items_add=frozenset({'Jack Ryan'}), confidence=0.22388059701492535, lift=4.163921276534793), OrderedStatistic(items_base=frozenset({'Atypical', 'Jack Ryan'}), items_add=frozenset({'Family Guy'}), confidence=0.26627218934911245, lift=3.7231998770460315), OrderedStatistic(items_base=frozenset({'Jack Ryan', 'Family Guy'}), items_add=frozenset({'Atypical'}), confidence=0.4368932038834951, lift=3.122046567574534)]),
#  RelationRecord(items=frozenset({'Atypical', 'Mr. Robot', 'Family Guy'}), support=0.006398348813209494, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Atypical', 'Mr. Robot'}), items_add=frozenset({'Family Guy'}), confidence=0.24701195219123506, lift=3.4538900674358843)]),
#  RelationRecord(items=frozenset({'Ozark', 'Atypical', 'Family Guy'}), support=0.01021671826625387, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Ozark', 'Atypical'}), items_add=frozenset({'Family Guy'}), confidence=0.23349056603773585, lift=3.2648247978436657)]),
#  RelationRecord(items=frozenset({'Atypical', 'The Blacklist', 'Family Guy'}), support=0.006191950464396285, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Blacklist', 'Family Guy'}), items_add=frozenset({'Atypical'}), confidence=0.44776119402985076, lift=3.199709417514199)]),
#  RelationRecord(items=frozenset({'Atypical', 'Jack Ryan', 'Mr. Robot'}), support=0.004747162022703818, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Mr. Robot', 'Jack Ryan'}), items_add=frozenset({'Atypical'}), confidence=0.42990654205607476, lift=3.0721197584980566)]),
#  RelationRecord(items=frozenset({'Atypical', 'Jack Ryan', 'The Blacklist'}), support=0.005366357069143447, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Jack Ryan', 'The Blacklist'}), items_add=frozenset({'Atypical'}), confidence=0.52, lift=3.7159292035398233)]),
#  RelationRecord(items=frozenset({'Atypical', 'The Blacklist', 'Mr. Robot'}), support=0.008255933952528379, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Atypical', 'Mr. Robot'}), items_add=frozenset({'The Blacklist'}), confidence=0.3187250996015936, lift=3.0398092668695296)]),
#  RelationRecord(items=frozenset({'Berlin Station', 'Ozark', 'Dr. House'}), support=0.0046439628482972135, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Berlin Station', 'Ozark'}), items_add=frozenset({'Dr. House'}), confidence=0.23076923076923075, lift=3.6301198801198797), OrderedStatistic(items_base=frozenset({'Dr. House', 'Ozark'}), items_add=frozenset({'Berlin Station'}), confidence=0.20737327188940094, lift=3.7350316070786156)]),
#  RelationRecord(items=frozenset({'Berlin Station', 'Dr. House', 'Sex Education'}), support=0.005985552115583075, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Berlin Station', 'Sex Education'}), items_add=frozenset({'Dr. House'}), confidence=0.21722846441947563, lift=3.417116591273894)]),
#  RelationRecord(items=frozenset({'Berlin Station', 'Ozark', 'Family Guy'}), support=0.0058823529411764705, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Berlin Station', 'Ozark'}), items_add=frozenset({'Family Guy'}), confidence=0.2923076923076923, lift=4.087246087246087), OrderedStatistic(items_base=frozenset({'Ozark', 'Family Guy'}), items_add=frozenset({'Berlin Station'}), confidence=0.20212765957446807, lift=3.640552084157241)]),
#  RelationRecord(items=frozenset({'Berlin Station', 'Sex Education', 'Family Guy'}), support=0.006811145510835914, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Berlin Station', 'Sex Education'}), items_add=frozenset({'Family Guy'}), confidence=0.24719101123595508, lift=3.4563937934724454), OrderedStatistic(items_base=frozenset({'Sex Education', 'Family Guy'}), items_add=frozenset({'Berlin Station'}), confidence=0.21086261980830673, lift=3.7978787842797255)]),
#  RelationRecord(items=frozenset({'Cobra Kai', 'The Blacklist', 'Demon Slayer'}), support=0.005675954592363261, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cobra Kai', 'Demon Slayer'}), items_add=frozenset({'The Blacklist'}), confidence=0.4135338345864662, lift=3.944038245219348), OrderedStatistic(items_base=frozenset({'Cobra Kai', 'The Blacklist'}), items_add=frozenset({'Demon Slayer'}), confidence=0.28061224489795916, lift=3.7197437114380634), OrderedStatistic(items_base=frozenset({'The Blacklist', 'Demon Slayer'}), items_add=frozenset({'Cobra Kai'}), confidence=0.275, lift=3.310248447204969)]),
#  RelationRecord(items=frozenset({'Ozark', 'Cobra Kai', 'Mr. Robot'}), support=0.01042311661506708, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cobra Kai', 'Mr. Robot'}), items_add=frozenset({'Ozark'}), confidence=0.5872093023255814, lift=3.0314641126983934), OrderedStatistic(items_base=frozenset({'Ozark', 'Cobra Kai'}), items_add=frozenset({'Mr. Robot'}), confidence=0.36071428571428577, lift=3.297473045822103)]),
#  RelationRecord(items=frozenset({'Cobra Kai', 'Mr. Robot', 'The Blacklist'}), support=0.005779153766769866, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cobra Kai', 'Mr. Robot'}), items_add=frozenset({'The Blacklist'}), confidence=0.3255813953488372, lift=3.1052005127266065), OrderedStatistic(items_base=frozenset({'Mr. Robot', 'The Blacklist'}), items_add=frozenset({'Cobra Kai'}), confidence=0.27450980392156865, lift=3.304347826086957)]),
#  RelationRecord(items=frozenset({'Ozark', 'Cobra Kai', 'The Blacklist'}), support=0.009184726522187823, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Ozark', 'Cobra Kai'}), items_add=frozenset({'The Blacklist'}), confidence=0.3178571428571429, lift=3.0315312148481444), OrderedStatistic(items_base=frozenset({'Ozark', 'The Blacklist'}), items_add=frozenset({'Cobra Kai'}), confidence=0.2564841498559078, lift=3.087368213793474)]),
#  RelationRecord(items=frozenset({'Two and a half men', 'Daredevil', 'Lucifer'}), support=0.00608875128998968, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Two and a half men', 'Lucifer'}), items_add=frozenset({'Daredevil'}), confidence=0.31216931216931215, lift=3.3240886098028954)]),
#  RelationRecord(items=frozenset({'Ozark', 'Mr. Robot', 'Deception'}), support=0.006191950464396285, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Ozark', 'Deception'}), items_add=frozenset({'Mr. Robot'}), confidence=0.3488372093023256, lift=3.1888986397542785)]),
#  RelationRecord(items=frozenset({'Ozark', 'Demon Slayer', 'Family Guy'}), support=0.005572755417956657, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Demon Slayer', 'Family Guy'}), items_add=frozenset({'Ozark'}), confidence=0.6000000000000001, lift=3.097496004262121)]),
#  RelationRecord(items=frozenset({'Mr. Robot', 'The Blacklist', 'Demon Slayer'}), support=0.005366357069143447, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Mr. Robot', 'Demon Slayer'}), items_add=frozenset({'The Blacklist'}), confidence=0.3443708609271523, lift=3.2844031913229386), OrderedStatistic(items_base=frozenset({'Mr. Robot', 'The Blacklist'}), items_add=frozenset({'Demon Slayer'}), confidence=0.2549019607843137, lift=3.3789329685362515)]),
#  RelationRecord(items=frozenset({'Ozark', 'The Blacklist', 'Demon Slayer'}), support=0.009597523219814242, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Ozark', 'Demon Slayer'}), items_add=frozenset({'The Blacklist'}), confidence=0.3675889328063241, lift=3.5058432666272443), OrderedStatistic(items_base=frozenset({'Ozark', 'The Blacklist'}), items_add=frozenset({'Demon Slayer'}), confidence=0.2680115273775216, lift=3.5527109443066816)]),
#  RelationRecord(items=frozenset({'Two and a half men', 'The Blacklist', 'Demon Slayer'}), support=0.004540763673890609, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Two and a half men', 'Demon Slayer'}), items_add=frozenset({'The Blacklist'}), confidence=0.3283582089552239, lift=3.1316840991890937)]),
#  RelationRecord(items=frozenset({'Dr. House', 'Ozark', 'Family Guy'}), support=0.005056759545923633, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Dr. House', 'Ozark'}), items_add=frozenset({'Family Guy'}), confidence=0.22580645161290325, lift=3.157380254154448)]),
#  RelationRecord(items=frozenset({'Jack Ryan', 'Sex Education', 'Family Guy'}), support=0.005985552115583075, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Jack Ryan', 'Sex Education'}), items_add=frozenset({'Family Guy'}), confidence=0.2265625, lift=3.16795183982684)]),
#  RelationRecord(items=frozenset({'Mr. Robot', 'The Blacklist', 'Family Guy'}), support=0.004540763673890609, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Blacklist', 'Family Guy'}), items_add=frozenset({'Mr. Robot'}), confidence=0.3283582089552239, lift=3.0016896648831315), OrderedStatistic(items_base=frozenset({'Mr. Robot', 'The Blacklist'}), items_add=frozenset({'Family Guy'}), confidence=0.21568627450980393, lift=3.0158730158730163)]),
#  RelationRecord(items=frozenset({'Ozark', 'The Blacklist', 'Family Guy'}), support=0.007946336429308566, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Ozark', 'The Blacklist'}), items_add=frozenset({'Family Guy'}), confidence=0.2219020172910663, lift=3.1027857829010568)]),
#  RelationRecord(items=frozenset({'Ozark', 'The Wire', 'Family Guy'}), support=0.004850361197110423, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Ozark', 'The Wire'}), items_add=frozenset({'Family Guy'}), confidence=0.21559633027522934, lift=3.0146153540648952)]),
#  RelationRecord(items=frozenset({'Mr. Robot', 'Only Murders in the building', 'Sex Education'}), support=0.004540763673890609, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Only Murders in the building', 'Sex Education'}), items_add=frozenset({'Mr. Robot'}), confidence=0.3963963963963964, lift=3.623661397246303)]),
#  RelationRecord(items=frozenset({'Ozark', 'Mr. Robot', 'Queen of the South'}), support=0.00804953560371517, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Ozark', 'Queen of the South'}), items_add=frozenset({'Mr. Robot'}), confidence=0.40414507772020725, lift=3.694496040668687)]),
#  RelationRecord(items=frozenset({'Ozark', 'Mr. Robot', 'Succession'}), support=0.005779153766769866, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Mr. Robot', 'Succession'}), items_add=frozenset({'Ozark'}), confidence=0.6021505376344086, lift=3.108598140478114), OrderedStatistic(items_base=frozenset({'Ozark', 'Succession'}), items_add=frozenset({'Mr. Robot'}), confidence=0.4028776978417266, lift=3.6829102755531427)]),
#  RelationRecord(items=frozenset({'Ozark', 'Mr. Robot', 'The Blacklist'}), support=0.012487100103199174, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Mr. Robot', 'The Blacklist'}), items_add=frozenset({'Ozark'}), confidence=0.5931372549019608, lift=3.0620671283963774), OrderedStatistic(items_base=frozenset({'Ozark', 'The Blacklist'}), items_add=frozenset({'Mr. Robot'}), confidence=0.3487031700288184, lift=3.187673318470991)]),
#  RelationRecord(items=frozenset({'Mr. Robot', 'Queen of the South', 'Sex Education'}), support=0.00804953560371517, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Queen of the South', 'Sex Education'}), items_add=frozenset({'Mr. Robot'}), confidence=0.3768115942028985, lift=3.444626743232157)]),
#  RelationRecord(items=frozenset({'Two and a half men', 'Mr. Robot', 'Queen of the South'}), support=0.005056759545923633, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Two and a half men', 'Mr. Robot'}), items_add=frozenset({'Queen of the South'}), confidence=0.2058823529411765, lift=3.9117647058823537), OrderedStatistic(items_base=frozenset({'Two and a half men', 'Queen of the South'}), items_add=frozenset({'Mr. Robot'}), confidence=0.3712121212121212, lift=3.3934391080617496)]),
#  RelationRecord(items=frozenset({'Mr. Robot', 'Succession', 'Sex Education'}), support=0.004850361197110423, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Succession', 'Sex Education'}), items_add=frozenset({'Mr. Robot'}), confidence=0.3949579831932773, lift=3.6105121293800537)]),
#  RelationRecord(items=frozenset({'Mr. Robot', 'The Stranger', 'Sex Education'}), support=0.005985552115583075, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Stranger', 'Sex Education'}), items_add=frozenset({'Mr. Robot'}), confidence=0.3372093023255814, lift=3.0826020184291356)]),
#  RelationRecord(items=frozenset({'Ozark', 'Queen of the South', 'The Blacklist'}), support=0.004540763673890609, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Queen of the South', 'The Blacklist'}), items_add=frozenset({'Ozark'}), confidence=0.5866666666666667, lift=3.028662759722962)]),
#  RelationRecord(items=frozenset({'Ozark', 'The Mentalist', 'The Blacklist'}), support=0.006707946336429308, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Ozark', 'The Mentalist'}), items_add=frozenset({'The Blacklist'}), confidence=0.3170731707317073, lift=3.024054157864413)]),
#  RelationRecord(items=frozenset({'Ozark', 'Atypical', 'Demon Slayer', 'Sex Education'}), support=0.005056759545923633, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Atypical', 'Demon Slayer'}), items_add=frozenset({'Ozark', 'Sex Education'}), confidence=0.28, lift=3.726923076923077)]),
#  RelationRecord(items=frozenset({'Ozark', 'Atypical', 'Sex Education', 'Family Guy'}), support=0.005572755417956657, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Atypical', 'Family Guy'}), items_add=frozenset({'Ozark', 'Sex Education'}), confidence=0.26865671641791045, lift=3.5759389863867472), OrderedStatistic(items_base=frozenset({'Ozark', 'Atypical', 'Sex Education'}), items_add=frozenset({'Family Guy'}), confidence=0.24884792626728114, lift=3.479561912741637)]),
#  RelationRecord(items=frozenset({'Ozark', 'Atypical', 'Mr. Robot', 'Sex Education'}), support=0.00784313725490196, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Atypical', 'Mr. Robot'}), items_add=frozenset({'Ozark', 'Sex Education'}), confidence=0.30278884462151395, lift=4.030252615909986), OrderedStatistic(items_base=frozenset({'Ozark', 'Atypical', 'Sex Education'}), items_add=frozenset({'Mr. Robot'}), confidence=0.3502304147465438, lift=3.2016346404660467)]),
#  RelationRecord(items=frozenset({'Ozark', 'Atypical', 'The Blacklist', 'Mr. Robot'}), support=0.005056759545923633, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Mr. Robot', 'The Blacklist'}), items_add=frozenset({'Ozark', 'Atypical'}), confidence=0.24019607843137256, lift=5.489386792452831), OrderedStatistic(items_base=frozenset({'Ozark', 'Atypical', 'Mr. Robot'}), items_add=frozenset({'The Blacklist'}), confidence=0.3888888888888889, lift=3.708989501312336), OrderedStatistic(items_base=frozenset({'Atypical', 'The Blacklist', 'Mr. Robot'}), items_add=frozenset({'Ozark'}), confidence=0.6125, lift=3.1620271710175816), OrderedStatistic(items_base=frozenset({'Ozark', 'Atypical', 'The Blacklist'}), items_add=frozenset({'Mr. Robot'}), confidence=0.40495867768595045, lift=3.701933572431)]),
#  RelationRecord(items=frozenset({'Atypical', 'The Blacklist', 'Mr. Robot', 'Sex Education'}), support=0.005779153766769866, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Atypical', 'Mr. Robot'}), items_add=frozenset({'The Blacklist', 'Sex Education'}), confidence=0.22310756972111553, lift=5.272956952677096), OrderedStatistic(items_base=frozenset({'Mr. Robot', 'The Blacklist'}), items_add=frozenset({'Atypical', 'Sex Education'}), confidence=0.27450980392156865, lift=4.889705882352941), OrderedStatistic(items_base=frozenset({'Atypical', 'Mr. Robot', 'Sex Education'}), items_add=frozenset({'The Blacklist'}), confidence=0.3971631205673759, lift=3.787904171553024), OrderedStatistic(items_base=frozenset({'Atypical', 'The Blacklist', 'Sex Education'}), items_add=frozenset({'Mr. Robot'}), confidence=0.37583892617449666, lift=3.435735089274408), OrderedStatistic(items_base=frozenset({'Mr. Robot', 'The Blacklist', 'Sex Education'}), items_add=frozenset({'Atypical'}), confidence=0.4827586206896552, lift=3.4498016478486426)]),
#  RelationRecord(items=frozenset({'Ozark', 'Atypical', 'The Blacklist', 'Sex Education'}), support=0.007739938080495356, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Atypical', 'The Blacklist'}), items_add=frozenset({'Ozark', 'Sex Education'}), confidence=0.2613240418118467, lift=3.4783378642263663), OrderedStatistic(items_base=frozenset({'Ozark', 'The Blacklist'}), items_add=frozenset({'Atypical', 'Sex Education'}), confidence=0.21613832853025935, lift=3.8499639769452445), OrderedStatistic(items_base=frozenset({'Ozark', 'Atypical', 'Sex Education'}), items_add=frozenset({'The Blacklist'}), confidence=0.3456221198156682, lift=3.2963369498167565), OrderedStatistic(items_base=frozenset({'Ozark', 'The Blacklist', 'Sex Education'}), items_add=frozenset({'Atypical'}), confidence=0.4491017964071856, lift=3.2092893858301097)]),
#  RelationRecord(items=frozenset({'Ozark', 'Atypical', 'The Mentalist', 'Sex Education'}), support=0.005159958720330237, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Atypical', 'The Mentalist'}), items_add=frozenset({'Ozark', 'Sex Education'}), confidence=0.2747252747252747, lift=3.6567141649559227), OrderedStatistic(items_base=frozenset({'Ozark', 'The Mentalist'}), items_add=frozenset({'Atypical', 'Sex Education'}), confidence=0.24390243902439024, lift=4.344512195121951), OrderedStatistic(items_base=frozenset({'Ozark', 'Atypical', 'Sex Education'}), items_add=frozenset({'The Mentalist'}), confidence=0.2304147465437788, lift=3.1759870469547886), OrderedStatistic(items_base=frozenset({'Ozark', 'The Mentalist', 'Sex Education'}), items_add=frozenset({'Atypical'}), confidence=0.4901960784313726, lift=3.502949852507375)]),
#  RelationRecord(items=frozenset({'Two and a half men', 'Atypical', 'The Blacklist', 'Sex Education'}), support=0.004953560371517028, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Two and a half men', 'The Blacklist'}), items_add=frozenset({'Atypical', 'Sex Education'}), confidence=0.200836820083682, lift=3.577405857740586), OrderedStatistic(items_base=frozenset({'Two and a half men', 'The Blacklist', 'Sex Education'}), items_add=frozenset({'Atypical'}), confidence=0.4571428571428572, lift=3.266750948166878)]),
#  RelationRecord(items=frozenset({'Ozark', 'Cobra Kai', 'Mr. Robot', 'Sex Education'}), support=0.005779153766769866, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cobra Kai', 'Mr. Robot'}), items_add=frozenset({'Ozark', 'Sex Education'}), confidence=0.3255813953488372, lift=4.3336314847942745), OrderedStatistic(items_base=frozenset({'Ozark', 'Cobra Kai'}), items_add=frozenset({'Mr. Robot', 'Sex Education'}), confidence=0.2, lift=4.088607594936709), OrderedStatistic(items_base=frozenset({'Cobra Kai', 'Mr. Robot', 'Sex Education'}), items_add=frozenset({'Ozark'}), confidence=0.6292134831460674, lift=3.248310416454658), OrderedStatistic(items_base=frozenset({'Ozark', 'Cobra Kai', 'Sex Education'}), items_add=frozenset({'Mr. Robot'}), confidence=0.4409448818897638, lift=4.030901797652652), OrderedStatistic(items_base=frozenset({'Ozark', 'Mr. Robot', 'Sex Education'}), items_add=frozenset({'Cobra Kai'}), confidence=0.25, lift=3.0093167701863357)]),
#  RelationRecord(items=frozenset({'Ozark', 'Cobra Kai', 'Mr. Robot', 'The Blacklist'}), support=0.004540763673890609, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cobra Kai', 'Mr. Robot'}), items_add=frozenset({'Ozark', 'The Blacklist'}), confidence=0.2558139534883721, lift=7.143623081562898), OrderedStatistic(items_base=frozenset({'Cobra Kai', 'The Blacklist'}), items_add=frozenset({'Ozark', 'Mr. Robot'}), confidence=0.22448979591836735, lift=4.7186683784142724), OrderedStatistic(items_base=frozenset({'Mr. Robot', 'The Blacklist'}), items_add=frozenset({'Ozark', 'Cobra Kai'}), confidence=0.21568627450980393, lift=7.464285714285714), OrderedStatistic(items_base=frozenset({'Ozark', 'Cobra Kai', 'Mr. Robot'}), items_add=frozenset({'The Blacklist'}), confidence=0.4356435643564356, lift=4.154907616745926), OrderedStatistic(items_base=frozenset({'Cobra Kai', 'Mr. Robot', 'The Blacklist'}), items_add=frozenset({'Ozark'}), confidence=0.7857142857142857, lift=4.05624476748611), OrderedStatistic(items_base=frozenset({'Ozark', 'Cobra Kai', 'The Blacklist'}), items_add=frozenset({'Mr. Robot'}), confidence=0.4943820224719101, lift=4.51939792240831), OrderedStatistic(items_base=frozenset({'Ozark', 'Mr. Robot', 'The Blacklist'}), items_add=frozenset({'Cobra Kai'}), confidence=0.36363636363636365, lift=4.3771880293619425)]),
#  RelationRecord(items=frozenset({'Ozark', 'Cobra Kai', 'The Blacklist', 'Sex Education'}), support=0.005056759545923633, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cobra Kai', 'The Blacklist'}), items_add=frozenset({'Ozark', 'Sex Education'}), confidence=0.25, lift=3.32760989010989), OrderedStatistic(items_base=frozenset({'Ozark', 'Cobra Kai', 'Sex Education'}), items_add=frozenset({'The Blacklist'}), confidence=0.3858267716535433, lift=3.6797848595697187), OrderedStatistic(items_base=frozenset({'Ozark', 'The Blacklist', 'Sex Education'}), items_add=frozenset({'Cobra Kai'}), confidence=0.2934131736526946, lift=3.531892736266597)]),
#  RelationRecord(items=frozenset({'Ozark', 'Mr. Robot', 'Demon Slayer', 'Sex Education'}), support=0.005469556243550051, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Mr. Robot', 'Demon Slayer'}), items_add=frozenset({'Ozark', 'Sex Education'}), confidence=0.35099337748344367, lift=4.671876137107924), OrderedStatistic(items_base=frozenset({'Ozark', 'Demon Slayer'}), items_add=frozenset({'Mr. Robot', 'Sex Education'}), confidence=0.20948616600790512, lift=4.282533646870466), OrderedStatistic(items_base=frozenset({'Mr. Robot', 'Demon Slayer', 'Sex Education'}), items_add=frozenset({'Ozark'}), confidence=0.6162790697674418, lift=3.181536593525046), OrderedStatistic(items_base=frozenset({'Ozark', 'Demon Slayer', 'Sex Education'}), items_add=frozenset({'Mr. Robot'}), confidence=0.4045801526717557, lift=3.6984732824427478), OrderedStatistic(items_base=frozenset({'Ozark', 'Mr. Robot', 'Sex Education'}), items_add=frozenset({'Demon Slayer'}), confidence=0.23660714285714285, lift=3.136420265780731)]),
#  RelationRecord(items=frozenset({'Ozark', 'The Blacklist', 'Demon Slayer', 'Sex Education'}), support=0.004850361197110423, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Blacklist', 'Demon Slayer'}), items_add=frozenset({'Ozark', 'Sex Education'}), confidence=0.235, lift=3.1279532967032964), OrderedStatistic(items_base=frozenset({'Ozark', 'Demon Slayer', 'Sex Education'}), items_add=frozenset({'The Blacklist'}), confidence=0.35877862595419846, lift=3.4218158321812826), OrderedStatistic(items_base=frozenset({'Ozark', 'The Blacklist', 'Sex Education'}), items_add=frozenset({'Demon Slayer'}), confidence=0.28143712574850294, lift=3.730678178526667)]),
#  RelationRecord(items=frozenset({'Dr. House', 'Mr. Robot', 'Ozark', 'Sex Education'}), support=0.004540763673890609, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Dr. House', 'Mr. Robot'}), items_add=frozenset({'Ozark', 'Sex Education'}), confidence=0.3142857142857143, lift=4.183281004709576), OrderedStatistic(items_base=frozenset({'Dr. House', 'Ozark'}), items_add=frozenset({'Mr. Robot', 'Sex Education'}), confidence=0.20276497695852536, lift=4.145132123898968), OrderedStatistic(items_base=frozenset({'Dr. House', 'Ozark', 'Sex Education'}), items_add=frozenset({'Mr. Robot'}), confidence=0.36666666666666664, lift=3.35188679245283)]),
#  RelationRecord(items=frozenset({'Ozark', 'Mr. Robot', 'Sex Education', 'Family Guy'}), support=0.005056759545923633, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Mr. Robot', 'Family Guy'}), items_add=frozenset({'Ozark', 'Sex Education'}), confidence=0.29878048780487804, lift=3.976899624765478), OrderedStatistic(items_base=frozenset({'Ozark', 'Sex Education', 'Family Guy'}), items_add=frozenset({'Mr. Robot'}), confidence=0.3450704225352113, lift=3.154464522986979), OrderedStatistic(items_base=frozenset({'Ozark', 'Mr. Robot', 'Sex Education'}), items_add=frozenset({'Family Guy'}), confidence=0.21875, lift=3.058712121212121)]),
#  RelationRecord(items=frozenset({'Ozark', 'Sex Education', 'The Blacklist', 'Family Guy'}), support=0.004540763673890609, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Blacklist', 'Family Guy'}), items_add=frozenset({'Ozark', 'Sex Education'}), confidence=0.3283582089552239, lift=4.370592094472691), OrderedStatistic(items_base=frozenset({'Ozark', 'The Blacklist', 'Sex Education'}), items_add=frozenset({'Family Guy'}), confidence=0.26347305389221554, lift=3.684060450527516)]),
#  RelationRecord(items=frozenset({'Ozark', 'Mr. Robot', 'The Blacklist', 'Sex Education'}), support=0.0071207430340557275, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Mr. Robot', 'The Blacklist'}), items_add=frozenset({'Ozark', 'Sex Education'}), confidence=0.3382352941176471, lift=4.50206043956044), OrderedStatistic(items_base=frozenset({'Mr. Robot', 'The Blacklist', 'Sex Education'}), items_add=frozenset({'Ozark'}), confidence=0.5948275862068966, lift=3.07079345250124), OrderedStatistic(items_base=frozenset({'Ozark', 'The Blacklist', 'Sex Education'}), items_add=frozenset({'Mr. Robot'}), confidence=0.41317365269461076, lift=3.7770308439724323)]),
#  RelationRecord(items=frozenset({'Ozark', 'Mr. Robot', 'Two and a half men', 'Sex Education'}), support=0.00629514963880289, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Two and a half men', 'Mr. Robot'}), items_add=frozenset({'Ozark', 'Sex Education'}), confidence=0.2563025210084034, lift=3.411499215070644), OrderedStatistic(items_base=frozenset({'Ozark', 'Two and a half men', 'Sex Education'}), items_add=frozenset({'Mr. Robot'}), confidence=0.3465909090909091, lift=3.1683640651801035)])]

# %% [markdown]
# Son 66 reglas. A manera de ejemplo se imprime la primera regla:

# %%
print(ResultadosC1[0])
# Out:
# RelationRecord(items=frozenset({'Alice in Borderland', 'Daredevil'}), support=0.0071207430340557275, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Alice in Borderland'}), items_add=frozenset({'Daredevil'}), confidence=0.2875, lift=3.061401098901099)])

# %% [markdown]
# La primera regla contiene dos elementos **Alice in Wonderland** y **Daredevil** que exclusivamente se compran juntos.
#
# * Esto tiene sentido, el genero y tematica de alice in wonderland es .. por lo tanto similar alde daredevil.
#
# * El soporte es de 0.0071, la confianza de 0.2875, la elevación de 3.06, esto es, 3.06 veces más posible de que vean Daredevl

# %%
print(ResultadosC1[1])
print(ResultadosC1[2])
# Out:
# RelationRecord(items=frozenset({'Arrow', 'The Wire'}), support=0.005779153766769866, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Arrow'}), items_add=frozenset({'The Wire'}), confidence=0.22134387351778656, lift=3.367067714893802)])
# RelationRecord(items=frozenset({'Dark', 'The 100'}), support=0.0046439628482972135, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The 100'}), items_add=frozenset({'Dark'}), confidence=0.41666666666666663, lift=4.6730324074074066)])

# %%
for item in ResultadosC1:
  #El primer índice de la lista
  Emparejar = item[0]
  items = [x for x in Emparejar]
  print("Regla: " + str(item[0]))

  #El segundo índice de la lista
  print("Soporte: " + str(item[1]))

  #El tercer índice de la lista
  print("Confianza: " + str(item[2][0][2]))
  print("Lift: " + str(item[2][0][3])) 
  print("=====================================")
# Out:
# Regla: frozenset({'Alice in Borderland', 'Daredevil'})
# Soporte: 0.0071207430340557275
# Confianza: 0.2875
# Lift: 3.061401098901099
# =====================================
# Regla: frozenset({'Arrow', 'The Wire'})
# Soporte: 0.005779153766769866
# Confianza: 0.22134387351778656
# Lift: 3.367067714893802
# =====================================
# Regla: frozenset({'Dark', 'The 100'})
# Soporte: 0.0046439628482972135
# Confianza: 0.41666666666666663
# Lift: 4.6730324074074066
# =====================================
# Regla: frozenset({'Punisher', 'Family Guy'})
# Soporte: 0.0046439628482972135
# Confianza: 0.26011560693641617
# Lift: 3.6371143307559493
# =====================================
# Regla: frozenset({'Rick And Morty', 'Family Guy'})
# Soporte: 0.009184726522187823
# Confianza: 0.27639751552795033
# Lift: 3.8647791132263185
# =====================================
# Regla: frozenset({'Game of thrones', 'Vikings'})
# Soporte: 0.004850361197110423
# Confianza: 0.2797619047619047
# Lift: 8.29019222367846
# =====================================
# Regla: frozenset({'Mr. Robot', 'Person of Interest'})
# Soporte: 0.006914344685242518
# Confianza: 0.4294871794871795
# Lift: 3.926161103047896
# =====================================
# Regla: frozenset({'Mr. Robot', 'Queen of the South'})
# Soporte: 0.0173374613003096
# Confianza: 0.3294117647058824
# Lift: 3.011320754716982
# =====================================
# Regla: frozenset({'Dr. House', '12 Monkeys', 'Sex Education'})
# Soporte: 0.005159958720330237
# Confianza: 0.2127659574468085
# Lift: 3.3469190384083998
# =====================================
# Regla: frozenset({'Atypical', 'Alice in Borderland', 'Sex Education'})
# Soporte: 0.0046439628482972135
# Confianza: 0.42857142857142855
# Lift: 3.0625790139064475
# =====================================
# Regla: frozenset({'Berlin Station', 'Atypical', 'The Blacklist'})
# Soporte: 0.0046439628482972135
# Confianza: 0.31690140845070425
# Lift: 3.0224159920150826
# =====================================
# Regla: frozenset({'Atypical', 'The Blacklist', 'Demon Slayer'})
# Soporte: 0.006501547987616099
# Confianza: 0.36
# Lift: 3.4334645669291337
# =====================================
# Regla: frozenset({'Atypical', 'Jack Ryan', 'Family Guy'})
# Soporte: 0.0046439628482972135
# Confianza: 0.22388059701492535
# Lift: 4.163921276534793
# =====================================
# Regla: frozenset({'Atypical', 'Mr. Robot', 'Family Guy'})
# Soporte: 0.006398348813209494
# Confianza: 0.24701195219123506
# Lift: 3.4538900674358843
# =====================================
# Regla: frozenset({'Ozark', 'Atypical', 'Family Guy'})
# Soporte: 0.01021671826625387
# Confianza: 0.23349056603773585
# Lift: 3.2648247978436657
# =====================================
# Regla: frozenset({'Atypical', 'The Blacklist', 'Family Guy'})
# Soporte: 0.006191950464396285
# Confianza: 0.44776119402985076
# Lift: 3.199709417514199
# =====================================
# Regla: frozenset({'Atypical', 'Jack Ryan', 'Mr. Robot'})
# Soporte: 0.004747162022703818
# Confianza: 0.42990654205607476
# Lift: 3.0721197584980566
# =====================================
# Regla: frozenset({'Atypical', 'Jack Ryan', 'The Blacklist'})
# Soporte: 0.005366357069143447
# Confianza: 0.52
# Lift: 3.7159292035398233
# =====================================
# Regla: frozenset({'Atypical', 'The Blacklist', 'Mr. Robot'})
# Soporte: 0.008255933952528379
# Confianza: 0.3187250996015936
# Lift: 3.0398092668695296
# =====================================
# Regla: frozenset({'Berlin Station', 'Ozark', 'Dr. House'})
# Soporte: 0.0046439628482972135
# Confianza: 0.23076923076923075
# Lift: 3.6301198801198797
# =====================================
# Regla: frozenset({'Berlin Station', 'Dr. House', 'Sex Education'})
# Soporte: 0.005985552115583075
# Confianza: 0.21722846441947563
# Lift: 3.417116591273894
# =====================================
# Regla: frozenset({'Berlin Station', 'Ozark', 'Family Guy'})
# Soporte: 0.0058823529411764705
# Confianza: 0.2923076923076923
# Lift: 4.087246087246087
# =====================================
# Regla: frozenset({'Berlin Station', 'Sex Education', 'Family Guy'})
# Soporte: 0.006811145510835914
# Confianza: 0.24719101123595508
# Lift: 3.4563937934724454
# =====================================
# Regla: frozenset({'Cobra Kai', 'The Blacklist', 'Demon Slayer'})
# Soporte: 0.005675954592363261
# Confianza: 0.4135338345864662
# Lift: 3.944038245219348
# =====================================
# Regla: frozenset({'Ozark', 'Cobra Kai', 'Mr. Robot'})
# Soporte: 0.01042311661506708
# Confianza: 0.5872093023255814
# Lift: 3.0314641126983934
# =====================================
# Regla: frozenset({'Cobra Kai', 'Mr. Robot', 'The Blacklist'})
# Soporte: 0.005779153766769866
# Confianza: 0.3255813953488372
# Lift: 3.1052005127266065
# =====================================
# Regla: frozenset({'Ozark', 'Cobra Kai', 'The Blacklist'})
# Soporte: 0.009184726522187823
# Confianza: 0.3178571428571429
# Lift: 3.0315312148481444
# =====================================
# Regla: frozenset({'Two and a half men', 'Daredevil', 'Lucifer'})
# Soporte: 0.00608875128998968
# Confianza: 0.31216931216931215
# Lift: 3.3240886098028954
# =====================================
# Regla: frozenset({'Ozark', 'Mr. Robot', 'Deception'})
# Soporte: 0.006191950464396285
# Confianza: 0.3488372093023256
# Lift: 3.1888986397542785
# =====================================
# Regla: frozenset({'Ozark', 'Demon Slayer', 'Family Guy'})
# Soporte: 0.005572755417956657
# Confianza: 0.6000000000000001
# Lift: 3.097496004262121
# =====================================
# Regla: frozenset({'Mr. Robot', 'The Blacklist', 'Demon Slayer'})
# Soporte: 0.005366357069143447
# Confianza: 0.3443708609271523
# Lift: 3.2844031913229386
# =====================================
# Regla: frozenset({'Ozark', 'The Blacklist', 'Demon Slayer'})
# Soporte: 0.009597523219814242
# Confianza: 0.3675889328063241
# Lift: 3.5058432666272443
# =====================================
# Regla: frozenset({'Two and a half men', 'The Blacklist', 'Demon Slayer'})
# Soporte: 0.004540763673890609
# Confianza: 0.3283582089552239
# Lift: 3.1316840991890937
# =====================================
# Regla: frozenset({'Dr. House', 'Ozark', 'Family Guy'})
# Soporte: 0.005056759545923633
# Confianza: 0.22580645161290325
# Lift: 3.157380254154448
# =====================================
# Regla: frozenset({'Jack Ryan', 'Sex Education', 'Family Guy'})
# Soporte: 0.005985552115583075
# Confianza: 0.2265625
# Lift: 3.16795183982684
# =====================================
# Regla: frozenset({'Mr. Robot', 'The Blacklist', 'Family Guy'})
# Soporte: 0.004540763673890609
# Confianza: 0.3283582089552239
# Lift: 3.0016896648831315
# =====================================
# Regla: frozenset({'Ozark', 'The Blacklist', 'Family Guy'})
# Soporte: 0.007946336429308566
# Confianza: 0.2219020172910663
# Lift: 3.1027857829010568
# =====================================
# Regla: frozenset({'Ozark', 'The Wire', 'Family Guy'})
# Soporte: 0.004850361197110423
# Confianza: 0.21559633027522934
# Lift: 3.0146153540648952
# =====================================
# Regla: frozenset({'Mr. Robot', 'Only Murders in the building', 'Sex Education'})
# Soporte: 0.004540763673890609
# Confianza: 0.3963963963963964
# Lift: 3.623661397246303
# =====================================
# Regla: frozenset({'Ozark', 'Mr. Robot', 'Queen of the South'})
# Soporte: 0.00804953560371517
# Confianza: 0.40414507772020725
# Lift: 3.694496040668687
# =====================================
# Regla: frozenset({'Ozark', 'Mr. Robot', 'Succession'})
# Soporte: 0.005779153766769866
# Confianza: 0.6021505376344086
# Lift: 3.108598140478114
# =====================================
# Regla: frozenset({'Ozark', 'Mr. Robot', 'The Blacklist'})
# Soporte: 0.012487100103199174
# Confianza: 0.5931372549019608
# Lift: 3.0620671283963774
# =====================================
# Regla: frozenset({'Mr. Robot', 'Queen of the South', 'Sex Education'})
# Soporte: 0.00804953560371517
# Confianza: 0.3768115942028985
# Lift: 3.444626743232157
# =====================================
# Regla: frozenset({'Two and a half men', 'Mr. Robot', 'Queen of the South'})
# Soporte: 0.005056759545923633
# Confianza: 0.2058823529411765
# Lift: 3.9117647058823537
# =====================================
# Regla: frozenset({'Mr. Robot', 'Succession', 'Sex Education'})
# Soporte: 0.004850361197110423
# Confianza: 0.3949579831932773
# Lift: 3.6105121293800537
# =====================================
# Regla: frozenset({'Mr. Robot', 'The Stranger', 'Sex Education'})
# Soporte: 0.005985552115583075
# Confianza: 0.3372093023255814
# Lift: 3.0826020184291356
# =====================================
# Regla: frozenset({'Ozark', 'Queen of the South', 'The Blacklist'})
# Soporte: 0.004540763673890609
# Confianza: 0.5866666666666667
# Lift: 3.028662759722962
# =====================================
# Regla: frozenset({'Ozark', 'The Mentalist', 'The Blacklist'})
# Soporte: 0.006707946336429308
# Confianza: 0.3170731707317073
# Lift: 3.024054157864413
# =====================================
# Regla: frozenset({'Ozark', 'Atypical', 'Demon Slayer', 'Sex Education'})
# Soporte: 0.005056759545923633
# Confianza: 0.28
# Lift: 3.726923076923077
# =====================================
# Regla: frozenset({'Ozark', 'Atypical', 'Sex Education', 'Family Guy'})
# Soporte: 0.005572755417956657
# Confianza: 0.26865671641791045
# Lift: 3.5759389863867472
# =====================================
# Regla: frozenset({'Ozark', 'Atypical', 'Mr. Robot', 'Sex Education'})
# Soporte: 0.00784313725490196
# Confianza: 0.30278884462151395
# Lift: 4.030252615909986
# =====================================
# Regla: frozenset({'Ozark', 'Atypical', 'The Blacklist', 'Mr. Robot'})
# Soporte: 0.005056759545923633
# Confianza: 0.24019607843137256
# Lift: 5.489386792452831
# =====================================
# Regla: frozenset({'Atypical', 'The Blacklist', 'Mr. Robot', 'Sex Education'})
# Soporte: 0.005779153766769866
# Confianza: 0.22310756972111553
# Lift: 5.272956952677096
# =====================================
# Regla: frozenset({'Ozark', 'Atypical', 'The Blacklist', 'Sex Education'})
# Soporte: 0.007739938080495356
# Confianza: 0.2613240418118467
# Lift: 3.4783378642263663
# =====================================
# Regla: frozenset({'Ozark', 'Atypical', 'The Mentalist', 'Sex Education'})
# Soporte: 0.005159958720330237
# Confianza: 0.2747252747252747
# Lift: 3.6567141649559227
# =====================================
# Regla: frozenset({'Two and a half men', 'Atypical', 'The Blacklist', 'Sex Education'})
# Soporte: 0.004953560371517028
# Confianza: 0.200836820083682
# Lift: 3.577405857740586
# =====================================
# Regla: frozenset({'Ozark', 'Cobra Kai', 'Mr. Robot', 'Sex Education'})
# Soporte: 0.005779153766769866
# Confianza: 0.3255813953488372
# Lift: 4.3336314847942745
# =====================================
# Regla: frozenset({'Ozark', 'Cobra Kai', 'Mr. Robot', 'The Blacklist'})
# Soporte: 0.004540763673890609
# Confianza: 0.2558139534883721
# Lift: 7.143623081562898
# =====================================
# Regla: frozenset({'Ozark', 'Cobra Kai', 'The Blacklist', 'Sex Education'})
# Soporte: 0.005056759545923633
# Confianza: 0.25
# Lift: 3.32760989010989
# =====================================
# Regla: frozenset({'Ozark', 'Mr. Robot', 'Demon Slayer', 'Sex Education'})
# Soporte: 0.005469556243550051
# Confianza: 0.35099337748344367
# Lift: 4.671876137107924
# =====================================
# Regla: frozenset({'Ozark', 'The Blacklist', 'Demon Slayer', 'Sex Education'})
# Soporte: 0.004850361197110423
# Confianza: 0.235
# Lift: 3.1279532967032964
# =====================================
# Regla: frozenset({'Dr. House', 'Mr. Robot', 'Ozark', 'Sex Education'})
# Soporte: 0.004540763673890609
# Confianza: 0.3142857142857143
# Lift: 4.183281004709576
# =====================================
# Regla: frozenset({'Ozark', 'Mr. Robot', 'Sex Education', 'Family Guy'})
# Soporte: 0.005056759545923633
# Confianza: 0.29878048780487804
# Lift: 3.976899624765478
# =====================================
# Regla: frozenset({'Ozark', 'Sex Education', 'The Blacklist', 'Family Guy'})
# Soporte: 0.004540763673890609
# Confianza: 0.3283582089552239
# Lift: 4.370592094472691
# =====================================
# Regla: frozenset({'Ozark', 'Mr. Robot', 'The Blacklist', 'Sex Education'})
# Soporte: 0.0071207430340557275
# Confianza: 0.3382352941176471
# Lift: 4.50206043956044
# =====================================
# Regla: frozenset({'Ozark', 'Mr. Robot', 'Two and a half men', 'Sex Education'})
# Soporte: 0.00629514963880289
# Confianza: 0.2563025210084034
# Lift: 3.411499215070644
# =====================================

# %% [markdown]
# **REPORTE:**: Con mis datos se considera la practica 3: Hacer 3 configuracones,mostrar las más significativas con su interpretación
# - Objetivos
# - Descripción de la práctica
# - Desarrollo
# - Reglas interpretación
# - Conclusiones
#
# **Proyecto:** Agregar a esto una interfaz más user friendly

# %% [markdown]
# **Configuración 2**
#
# Obtener reglas para aquellos artículos que se compran al menos 30 veces al día, entonces, 30 x 7 = 210 veces en una semana, entonces:
#
# i) El soporte mínimo se calcula de 210/7500 = 0.028 (2.8%).
#
# ii) La confianza mínima para las reglas de 25%.
#
# iii) La elevación mayor a 1.

# %%
ReglasC2 = apriori(TransaccionesLista, 
                   min_support=0.028, 
                   min_confidence=0.25, 
                   min_lift = 1.01)

# %%
ResultadosC2 = list(ReglasC2)
print(len(ResultadosC2))
# Out:
# 10

# %%
ResultadosC2
# Out:
# [RelationRecord(items=frozenset({'burgers', 'eggs'}), support=0.02879616051193174, ordered_statistics=[OrderedStatistic(items_base=frozenset({'burgers'}), items_add=frozenset({'eggs'}), confidence=0.33027522935779813, lift=1.8378297443715457)]),
#  RelationRecord(items=frozenset({'chocolate', 'mineral water'}), support=0.05265964538061592, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chocolate'}), items_add=frozenset({'mineral water'}), confidence=0.3213995117982099, lift=1.3483320682317521)]),
#  RelationRecord(items=frozenset({'eggs', 'mineral water'}), support=0.05092654312758299, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs'}), items_add=frozenset({'mineral water'}), confidence=0.28338278931750743, lift=1.188844688294532)]),
#  RelationRecord(items=frozenset({'frozen vegetables', 'mineral water'}), support=0.03572856952406346, ordered_statistics=[OrderedStatistic(items_base=frozenset({'frozen vegetables'}), items_add=frozenset({'mineral water'}), confidence=0.37482517482517486, lift=1.57246288387228)]),
#  RelationRecord(items=frozenset({'ground beef', 'mineral water'}), support=0.040927876283162246, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ground beef'}), items_add=frozenset({'mineral water'}), confidence=0.41655359565807326, lift=1.7475215442008991)]),
#  RelationRecord(items=frozenset({'ground beef', 'spaghetti'}), support=0.03919477403012932, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ground beef'}), items_add=frozenset({'spaghetti'}), confidence=0.3989145183175034, lift=2.291162176033379)]),
#  RelationRecord(items=frozenset({'milk', 'mineral water'}), support=0.04799360085321957, ordered_statistics=[OrderedStatistic(items_base=frozenset({'milk'}), items_add=frozenset({'mineral water'}), confidence=0.3703703703703704, lift=1.5537741320739085)]),
#  RelationRecord(items=frozenset({'spaghetti', 'milk'}), support=0.03546193840821224, ordered_statistics=[OrderedStatistic(items_base=frozenset({'milk'}), items_add=frozenset({'spaghetti'}), confidence=0.27366255144032925, lift=1.5717785592296398)]),
#  RelationRecord(items=frozenset({'pancakes', 'mineral water'}), support=0.03372883615517931, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pancakes'}), items_add=frozenset({'mineral water'}), confidence=0.3548387096774194, lift=1.4886158620191963)]),
#  RelationRecord(items=frozenset({'spaghetti', 'mineral water'}), support=0.05972536995067324, ordered_statistics=[OrderedStatistic(items_base=frozenset({'mineral water'}), items_add=frozenset({'spaghetti'}), confidence=0.2505592841163311, lift=1.4390851379453289), OrderedStatistic(items_base=frozenset({'spaghetti'}), items_add=frozenset({'mineral water'}), confidence=0.3430321592649311, lift=1.4390851379453289)])]

# %%
print(ResultadosC2[0])
# Out:
# RelationRecord(items=frozenset({'burgers', 'eggs'}), support=0.02879616051193174, ordered_statistics=[OrderedStatistic(items_base=frozenset({'burgers'}), items_add=frozenset({'eggs'}), confidence=0.33027522935779813, lift=1.8378297443715457)])

# %% [markdown]
# La primera regla contiene dos elementos: **hamburguesas** y **huevos** que comúnmente se compran juntos.
#
# * Tiene sentido, algunas personas que compran hamburguesas consumen también huevos, como comida de preparación rápida.
#
# * El soporte es de 0.028 (2.8%), la confianza de 0.33 (33%), la elevación de 1.83, esto es, hay casi 2 veces más probabilidades de que cuando se compre posibilidades se compre también huevos.

# %%
print(ResultadosC2[1])
print(ResultadosC2[2])
# Out:
# RelationRecord(items=frozenset({'chocolate', 'mineral water'}), support=0.05265964538061592, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chocolate'}), items_add=frozenset({'mineral water'}), confidence=0.3213995117982099, lift=1.3483320682317521)])
# RelationRecord(items=frozenset({'mineral water', 'eggs'}), support=0.05092654312758299, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs'}), items_add=frozenset({'mineral water'}), confidence=0.28338278931750743, lift=1.188844688294532)])

# %%
for item in ResultadosC2:
  #El primer índice de la lista
  Emparejar = item[0]
  items = [x for x in Emparejar]
  print("Regla: " + str(item[0]))

  #El segundo índice de la lista
  print("Soporte: " + str(item[1]))

  #El tercer índice de la lista
  print("Confianza: " + str(item[2][0][2]))
  print("Lift: " + str(item[2][0][3])) 
  print("=====================================")
# Out:
# Regla: frozenset({'burgers', 'eggs'})
# Soporte: 0.02879616051193174
# Confianza: 0.33027522935779813
# Lift: 1.8378297443715457
# =====================================
# Regla: frozenset({'chocolate', 'mineral water'})
# Soporte: 0.05265964538061592
# Confianza: 0.3213995117982099
# Lift: 1.3483320682317521
# =====================================
# Regla: frozenset({'mineral water', 'eggs'})
# Soporte: 0.05092654312758299
# Confianza: 0.28338278931750743
# Lift: 1.188844688294532
# =====================================
# Regla: frozenset({'frozen vegetables', 'mineral water'})
# Soporte: 0.03572856952406346
# Confianza: 0.37482517482517486
# Lift: 1.57246288387228
# =====================================
# Regla: frozenset({'mineral water', 'ground beef'})
# Soporte: 0.040927876283162246
# Confianza: 0.41655359565807326
# Lift: 1.7475215442008991
# =====================================
# Regla: frozenset({'spaghetti', 'ground beef'})
# Soporte: 0.03919477403012932
# Confianza: 0.3989145183175034
# Lift: 2.291162176033379
# =====================================
# Regla: frozenset({'milk', 'mineral water'})
# Soporte: 0.04799360085321957
# Confianza: 0.3703703703703704
# Lift: 1.5537741320739085
# =====================================
# Regla: frozenset({'milk', 'spaghetti'})
# Soporte: 0.03546193840821224
# Confianza: 0.27366255144032925
# Lift: 1.5717785592296398
# =====================================
# Regla: frozenset({'pancakes', 'mineral water'})
# Soporte: 0.03372883615517931
# Confianza: 0.3548387096774194
# Lift: 1.4886158620191963
# =====================================
# Regla: frozenset({'spaghetti', 'mineral water'})
# Soporte: 0.05972536995067324
# Confianza: 0.2505592841163311
# Lift: 1.4390851379453289
# =====================================
